# %%
import re
from collections import Counter 

import pandas as pd
import numpy as np


import warnings
warnings.filterwarnings('ignore')

# %%
data_dir = "data/"
df = pd.read_csv(data_dir + "train.csv")
df = df.drop(columns=["id"])

# %%
# df = df[:200]
df
# Out:
#                                               raw_address  \
# 0       jl kapuk timur delta sili iii lippo cika 11 a ...
# 1                                      aye, jati sampurna
# 2                    setu siung 119 rt 5 1 13880 cipayung
# 3                                    toko dita, kertosono
# 4                                           jl. orde baru
# ...                                                   ...
# 299995               jend ahmad yani 331 kertasari ciamis
# 299996                 raya cila kko, cilandak timur kel.
# 299997                     tanjung gusta jl. yaya 2 no 17
# 299998  jalan cipadu jaya taman asri gang bijaksana 3 ...
# 299999          jaya maspion permata blok beryl b2  no.58
#
#                                        POI/street
# 0       /jl kapuk timur delta sili iii lippo cika
# 1                                               /
# 2                                          /siung
# 3                                      toko dita/
# 4                                  /jl. orde baru
# ...                                           ...
# 299995                           /jend ahmad yani
# 299996                             /raya cila kko
# 299997                                          /
# 299998                                taman asri/
# 299999                      jaya maspion permata/
#
# [300000 rows x 2 columns]

# %% [markdown]
# ### Remove whitespace

# %%
# remove multiple whitespace
# cover tabs, newlines, etc
def remove_multiple_whitespace(text) :
    return re.sub(' +', ' ', text.replace('\n', ' ').replace('\t', ' ')).strip()

# %%
remove_multiple_whitespace("asfua asfasbiuf \n \t  asfsa adfgas \t d ")
# Out:
# 'asfua asfasbiuf asfsa adfgas d'

# %%
df["raw_address"] = df["raw_address"].apply(remove_multiple_whitespace)
df["POI/street"] = df["POI/street"].apply(remove_multiple_whitespace)

# %% [markdown]
# ### Only use data with having at least POI or street

# %%
df = df[df["POI/street"] != "/"]
df.reset_index(drop=True, inplace=True)
df
# Out:
#                                               raw_address  \
# 0       jl kapuk timur delta sili iii lippo cika 11 a ...
# 1                    setu siung 119 rt 5 1 13880 cipayung
# 2                                    toko dita, kertosono
# 3                                           jl. orde baru
# 4                        raya samb gede, 299 toko bb kids
# ...                                                   ...
# 268002    karawaci baru kakap raya 156 rt 1 rw 3 karawaci
# 268003               jend ahmad yani 331 kertasari ciamis
# 268004                 raya cila kko, cilandak timur kel.
# 268005  jalan cipadu jaya taman asri gang bijaksana 3 ...
# 268006           jaya maspion permata blok beryl b2 no.58
#
#                                        POI/street
# 0       /jl kapuk timur delta sili iii lippo cika
# 1                                          /siung
# 2                                      toko dita/
# 3                                  /jl. orde baru
# 4                     toko bb kids/raya samb gede
# ...                                           ...
# 268002                                /kakap raya
# 268003                           /jend ahmad yani
# 268004                             /raya cila kko
# 268005                                taman asri/
# 268006                      jaya maspion permata/
#
# [268007 rows x 2 columns]

# %%
def getPOI(s) :
    return s.split("/")[0]

def getStreet(s) :
    return s.split("/")[1]

def split(s) :
    s = remove_multiple_whitespace(s)
    return s.split(" ")

# %%
df["POI"] = df["POI/street"].apply(getPOI)
df["Street"] = df["POI/street"].apply(getStreet)

# %%
# Empty POI
len(df[df['POI'] == ''])
# Out:
# 146516

# %%
# Empty Street
len(df[df['Street'] == ''])
# Out:
# 38150

# %% [markdown]
# ## Number of Dot in POI and Street

# %%
x = df["POI"].apply(lambda x : "." in x)
sum(x)
# Out:
# 6464

# %%
x = df["Street"].apply(lambda x : "." in x)
sum(x)
# Out:
# 29080

# %%
df["SplitPOI"] = df["POI"].apply(split)
df["SplitStreet"] = df["Street"].apply(split)
df["SplitRaw"] = df["raw_address"].apply(split)

# %%
dot_tokens = []

# %%
for tokens in df["SplitPOI"].tolist() + df["SplitStreet"].tolist() :
    for token in tokens :
        if "." in token :
            dot_tokens.append(token)

# %%
count = Counter(dot_tokens)

# %%
count.most_common()[:20]
# Out:
# [('gg.', 10709),
#  ('jl.', 9731),
#  ('h.', 2013),
#  ('dr.', 959),
#  ('pt.', 723),
#  ('kh.', 650),
#  ('a.', 602),
#  ('r.', 588),
#  ('s.', 575),
#  ('kel.', 547),
#  ('jln.', 507),
#  ('m.', 492),
#  ('ud.', 456),
#  ('ir.', 448),
#  ('p.', 384),
#  ('jend.', 291),
#  ('cv.', 256),
#  ('prof.', 221),
#  ('k.', 221),
#  ('kp.', 205)]

# %%
unique_dot_tokens = set(dot_tokens)

# %%
## remove dot if the token doesn't has 
def remove_dot(text) :
    words = text.split(" ")
    for i in range(len(words)) :
        if "." in words[i] and words[i] not in unique_dot_tokens :
            words[i] = words[i].replace(".", " ").strip()
    return " ".join(words)

# %%
words = ['batu', 'flower', 'garden.', 'ds.', 'dresel.', 'oro-oro', 'ombo.', 'batu.', 'kota', 'batu']
text = " ".join(words)
remove_dot(text)
# Out:
# 'batu flower garden ds. dresel oro-oro ombo batu kota batu'

# %%
df["raw_address"] = df["raw_address"].apply(remove_dot)

df["POI"] = df["POI/street"].apply(getPOI)
df["Street"] = df["POI/street"].apply(getStreet) 

df["SplitRaw"] = df["raw_address"].apply(split)
df["SplitPOI"] = df["POI"].apply(split)
df["SplitStreet"] = df["Street"].apply(split)
df.head()
# Out:
#                                          raw_address  \
# 0  jl kapuk timur delta sili iii lippo cika 11 a ...
# 1               setu siung 119 rt 5 1 13880 cipayung
# 2                               toko dita, kertosono
# 3                                      jl. orde baru
# 4                   raya samb gede, 299 toko bb kids
#
#                                   POI/street           POI  \
# 0  /jl kapuk timur delta sili iii lippo cika
# 1                                     /siung
# 2                                 toko dita/     toko dita
# 3                             /jl. orde baru
# 4                toko bb kids/raya samb gede  toko bb kids
#
#                                      Street          SplitPOI  \
# 0  jl kapuk timur delta sili iii lippo cika                []
# 1                                     siung                []
# 2                                                [toko, dita]
# 3                             jl. orde baru                []
# 4                            raya samb gede  [toko, bb, kids]
#
#                                          SplitStreet  \
# 0  [jl, kapuk, timur, delta, sili, iii, lippo, cika]
# 1                                            [siung]
# 2                                                 []
# 3                                  [jl., orde, baru]
# 4                                 [raya, samb, gede]
#
#                                             SplitRaw
# 0  [jl, kapuk, timur, delta, sili, iii, lippo, ci...
# 1      [setu, siung, 119, rt, 5, 1, 13880, cipayung]
# 2                           [toko, dita,, kertosono]
# 3                                  [jl., orde, baru]
# 4           [raya, samb, gede,, 299, toko, bb, kids]

# %% [markdown]
# ## Number of Comma in POI and Street

# %%
x = df["POI"].apply(lambda x : "," in x)
sum(x)
# Out:
# 918

# %%
x = df["Street"].apply(lambda x : "," in x)
sum(x)
# Out:
# 1176

# %%
comma_tokens = []

# %%
for tokens in df["SplitPOI"].tolist() + df["SplitStreet"].tolist() :
    for token in tokens :
        if "," in token :
            comma_tokens.append(token)

# %%
count = Counter(comma_tokens)

# %%
count.most_common()[:15]
# Out:
# [('ii,', 107),
#  ('raya,', 87),
#  ('i,', 66),
#  ('iii,', 56),
#  ('2,', 46),
#  ('baru,', 40),
#  ('iv,', 36),
#  ('1,', 35),
#  ('v,', 35),
#  ('jaya,', 30),
#  ('4,', 27),
#  ('sh.,', 26),
#  ('jl,', 26),
#  ('3,', 23),
#  ('lor,', 22)]

# %%
# since the number is small, and the occurance is odd
# we can omit space in raw_address
def remove_comma(text) :
    return remove_multiple_whitespace(text.replace(",", " , ")).strip()

# %%
df["raw_address"] = df["raw_address"].apply(remove_comma)
df["POI/street"] = df["POI/street"].apply(remove_comma)

df["POI"] = df["POI/street"].apply(getPOI)
df["Street"] = df["POI/street"].apply(getStreet) 

df["SplitRaw"] = df["raw_address"].apply(split)
df["SplitPOI"] = df["POI"].apply(split)
df["SplitStreet"] = df["Street"].apply(split)

df.head()
# Out:
#                                          raw_address  \
# 0  jl kapuk timur delta sili iii lippo cika 11 a ...
# 1               setu siung 119 rt 5 1 13880 cipayung
# 2                              toko dita , kertosono
# 3                                      jl. orde baru
# 4                  raya samb gede , 299 toko bb kids
#
#                                   POI/street           POI  \
# 0  /jl kapuk timur delta sili iii lippo cika
# 1                                     /siung
# 2                                 toko dita/     toko dita
# 3                             /jl. orde baru
# 4                toko bb kids/raya samb gede  toko bb kids
#
#                                      Street          SplitPOI  \
# 0  jl kapuk timur delta sili iii lippo cika                []
# 1                                     siung                []
# 2                                                [toko, dita]
# 3                             jl. orde baru                []
# 4                            raya samb gede  [toko, bb, kids]
#
#                                          SplitStreet  \
# 0  [jl, kapuk, timur, delta, sili, iii, lippo, cika]
# 1                                            [siung]
# 2                                                 []
# 3                                  [jl., orde, baru]
# 4                                 [raya, samb, gede]
#
#                                             SplitRaw
# 0  [jl, kapuk, timur, delta, sili, iii, lippo, ci...
# 1      [setu, siung, 119, rt, 5, 1, 13880, cipayung]
# 2                         [toko, dita, ,, kertosono]
# 3                                  [jl., orde, baru]
# 4         [raya, samb, gede, ,, 299, toko, bb, kids]

# %% [markdown]
# ## Number of ( in POI and Street

# %%
x = df["POI"].apply(lambda x : "(" in x)
sum(x)
# Out:
# 548

# %%
x = df["Street"].apply(lambda x : "(" in x)
sum(x)
# Out:
# 9

# %%
lb_tokens = []

# %%
for tokens in df["SplitPOI"].tolist() + df["SplitStreet"].tolist() :
    for token in tokens :
        if "(" in token :
            lb_tokens.append(token)

# %%
count = Counter(lb_tokens)

# %%
count.most_common()[:15]
# Out:
# [('(', 30),
#  ('(ra)', 24),
#  ('(sdn)', 20),
#  ('(mt)', 18),
#  ('(persero)', 14),
#  ('(mis)', 13),
#  ('(tpa', 12),
#  ('(tpq', 11),
#  ('(kua)', 9),
#  ('(tk)', 8),
#  ('(alfamart)', 7),
#  ('(tpq)', 7),
#  ('(smk)', 7),
#  ('(depan', 6),
#  ('(lkp)', 6)]

# %%
# remove "(" and ")" if it's not in one word
def remove_bracket(text) :
    words = text.split(" ")
    for i in range(len(words)) :
        if "(" in words[i] and  ")" not in words[i] :
            words[i] = words[i].replace("(", "")
        elif ")" in words[i] and  "(" not in words[i] :
            words[i] = words[i].replace(")", "")
    return " ".join(words).strip()

# %%
df["raw_address"] = df["raw_address"].apply(remove_bracket)
df["POI/street"] = df["POI/street"].apply(remove_bracket)

df["POI"] = df["POI/street"].apply(getPOI)
df["Street"] = df["POI/street"].apply(getStreet) 

df["SplitRaw"] = df["raw_address"].apply(split)
df["SplitPOI"] = df["POI"].apply(split)
df["SplitStreet"] = df["Street"].apply(split)

df.head()
# Out:
#                                          raw_address  \
# 0  jl kapuk timur delta sili iii lippo cika 11 a ...
# 1               setu siung 119 rt 5 1 13880 cipayung
# 2                              toko dita , kertosono
# 3                                      jl. orde baru
# 4                  raya samb gede , 299 toko bb kids
#
#                                   POI/street           POI  \
# 0  /jl kapuk timur delta sili iii lippo cika
# 1                                     /siung
# 2                                 toko dita/     toko dita
# 3                             /jl. orde baru
# 4                toko bb kids/raya samb gede  toko bb kids
#
#                                      Street          SplitPOI  \
# 0  jl kapuk timur delta sili iii lippo cika                []
# 1                                     siung                []
# 2                                                [toko, dita]
# 3                             jl. orde baru                []
# 4                            raya samb gede  [toko, bb, kids]
#
#                                          SplitStreet  \
# 0  [jl, kapuk, timur, delta, sili, iii, lippo, cika]
# 1                                            [siung]
# 2                                                 []
# 3                                  [jl., orde, baru]
# 4                                 [raya, samb, gede]
#
#                                             SplitRaw
# 0  [jl, kapuk, timur, delta, sili, iii, lippo, ci...
# 1      [setu, siung, 119, rt, 5, 1, 13880, cipayung]
# 2                         [toko, dita, ,, kertosono]
# 3                                  [jl., orde, baru]
# 4         [raya, samb, gede, ,, 299, toko, bb, kids]

# %%
def f(words, sentence): 
    res = []
    for word in words :
        if sentence.find(word) == -1 :
            res.append(word)
    if len(res) == 0 :
        return False
    return res

# %%
df['TransformedPOI'] = df.apply(lambda x: f(x.SplitPOI, x.raw_address), axis=1)
df['TransformedStreet'] = df.apply(lambda x: f(x.SplitStreet, x.raw_address), axis=1)

# %%
# dp = df[df["TransformedPOI"] != False]
# dp.head()

# %%
# ds = df[df["TransformedStreet"] != False]
# ds.head()

# %% [markdown]
# words = ['ds.', 'sukowiyono', 'dsn.', 'karangsono', 'rt', '01', 'rw', '03', 'utara', 'jembatan', 'simomasuk', 'gang', 'jembatan']
#
# POI = ['jembatan', 'simo']
#
# there is a corrector for misspell word

# %%
odds = []

def repair_words(words, repaireds) :
    i = 0
    while i < len(words) :
        curr = words[i]
        if curr == repaireds[0][:len(curr)] :
            j = 1
            while j < len(repaireds) :
                if i + j >= len(words) :
                    odds.append({"words": words, "repaireds": repaireds})
#                     print(i)
#                     print(j)
#                     print(words)
#                     print(repaireds)
                    return []
                curr = words[i+j]
                if curr == repaireds[j][:len(curr)] :
                    j += 1
                else :
                    break
            if j == len(repaireds) :
                words[i:i+j] = repaireds
                return words
        i += 1
    return words

# %%
df["clean_address"] = df.apply(lambda x : repair_words(x.SplitRaw, x.SplitPOI), axis=1)
df["clean_address"] = df.apply(lambda x : repair_words(x.clean_address, x.SplitStreet), axis=1)

# %%
### Number of odd case
len(odds)
# Out:
# 4

# %%
for odd in odds :
    print("Words\t\t: ", " ".join(odd["words"]))
    print("Repaireds\t: ", " ".join(odd["repaireds"]))
#     print(odd["repaireds"])
    print()
# Out:
# Words		:  pelab tadett ,
# Repaireds	:  pelabuhan tadette , , ,
#
# Words		:  cirebon waterland ade irma suryani. jl. yos sudarso no 1 , lemahwungkuk , cirebon
# Repaireds	:  cirebon waterland ade irma suryani
#
# Words		:  pamulang barat pamu squa lt. dasar siliw 3-6 15417 pamulang
# Repaireds	:  pamulang square , lt. dasar
#
# Words		:  asemr gg. i asem rowo asemrowo
# Repaireds	:  asemrowo , gg. i

# %%
df
# Out:
#                                               raw_address  \
# 0       jl kapuk timur delta sili iii lippo cika 11 a ...
# 1                    setu siung 119 rt 5 1 13880 cipayung
# 2                                   toko dita , kertosono
# 3                                           jl. orde baru
# 4                       raya samb gede , 299 toko bb kids
# ...                                                   ...
# 268002    karawaci baru kakap raya 156 rt 1 rw 3 karawaci
# 268003               jend ahmad yani 331 kertasari ciamis
# 268004                raya cila kko , cilandak timur kel.
# 268005  jalan cipadu jaya taman asri gang bijaksana 3 ...
# 268006           jaya maspion permata blok beryl b2 no 58
#
#                                        POI/street                   POI  \
# 0       /jl kapuk timur delta sili iii lippo cika
# 1                                          /siung
# 2                                      toko dita/             toko dita
# 3                                  /jl. orde baru
# 4                     toko bb kids/raya samb gede          toko bb kids
# ...                                           ...                   ...
# 268002                                /kakap raya
# 268003                           /jend ahmad yani
# 268004                             /raya cila kko
# 268005                                taman asri/            taman asri
# 268006                      jaya maspion permata/  jaya maspion permata
#
#                                           Street                  SplitPOI  \
# 0       jl kapuk timur delta sili iii lippo cika                        []
# 1                                          siung                        []
# 2                                                             [toko, dita]
# 3                                  jl. orde baru                        []
# 4                                 raya samb gede          [toko, bb, kids]
# ...                                          ...                       ...
# 268002                                kakap raya                        []
# 268003                           jend ahmad yani                        []
# 268004                             raya cila kko                        []
# 268005                                                       [taman, asri]
# 268006                                            [jaya, maspion, permata]
#
#                                               SplitStreet  \
# 0       [jl, kapuk, timur, delta, sili, iii, lippo, cika]
# 1                                                 [siung]
# 2                                                      []
# 3                                       [jl., orde, baru]
# 4                                      [raya, samb, gede]
# ...                                                   ...
# 268002                                      [kakap, raya]
# 268003                                [jend, ahmad, yani]
# 268004                                  [raya, cila, kko]
# 268005                                                 []
# 268006                                                 []
#
#                                                  SplitRaw TransformedPOI  \
# 0       [jl, kapuk, timur, delta, sili, iii, lippo, ci...          False
# 1           [setu, siung, 119, rt, 5, 1, 13880, cipayung]          False
# 2                              [toko, dita, ,, kertosono]          False
# 3                                       [jl., orde, baru]          False
# 4              [raya, samb, gede, ,, 299, toko, bb, kids]          False
# ...                                                   ...            ...
# 268002  [karawaci, baru, kakap, raya, 156, rt, 1, rw, ...          False
# 268003        [jend, ahmad, yani, 331, kertasari, ciamis]          False
# 268004        [raya, cila, kko, ,, cilandak, timur, kel.]          False
# 268005  [jalan, cipadu, jaya, taman, asri, gang, bijak...          False
# 268006  [jaya, maspion, permata, blok, beryl, b2, no, 58]          False
#
#        TransformedStreet                                      clean_address
# 0                  False  [jl, kapuk, timur, delta, sili, iii, lippo, ci...
# 1                  False      [setu, siung, 119, rt, 5, 1, 13880, cipayung]
# 2                  False                         [toko, dita, ,, kertosono]
# 3                  False                                  [jl., orde, baru]
# 4                  False         [raya, samb, gede, ,, 299, toko, bb, kids]
# ...                  ...                                                ...
# 268002             False  [karawaci, baru, kakap, raya, 156, rt, 1, rw, ...
# 268003             False        [jend, ahmad, yani, 331, kertasari, ciamis]
# 268004             False        [raya, cila, kko, ,, cilandak, timur, kel.]
# 268005             False  [jalan, cipadu, jaya, taman, asri, gang, bijak...
# 268006             False  [jaya, maspion, permata, blok, beryl, b2, no, 58]
#
# [268007 rows x 10 columns]

# %%
def array_to_string(arr) :
    return " ".join(arr)

# %%
df["clean_address"] = df["clean_address"].apply(array_to_string)

# %%
df["clean_address"] = df["clean_address"].replace("", np.nan)
df = df.dropna().reset_index(drop=True)
df
# Out:
#                                               raw_address  \
# 0       jl kapuk timur delta sili iii lippo cika 11 a ...
# 1                    setu siung 119 rt 5 1 13880 cipayung
# 2                                   toko dita , kertosono
# 3                                           jl. orde baru
# 4                       raya samb gede , 299 toko bb kids
# ...                                                   ...
# 267998    karawaci baru kakap raya 156 rt 1 rw 3 karawaci
# 267999               jend ahmad yani 331 kertasari ciamis
# 268000                raya cila kko , cilandak timur kel.
# 268001  jalan cipadu jaya taman asri gang bijaksana 3 ...
# 268002           jaya maspion permata blok beryl b2 no 58
#
#                                        POI/street                   POI  \
# 0       /jl kapuk timur delta sili iii lippo cika
# 1                                          /siung
# 2                                      toko dita/             toko dita
# 3                                  /jl. orde baru
# 4                     toko bb kids/raya samb gede          toko bb kids
# ...                                           ...                   ...
# 267998                                /kakap raya
# 267999                           /jend ahmad yani
# 268000                             /raya cila kko
# 268001                                taman asri/            taman asri
# 268002                      jaya maspion permata/  jaya maspion permata
#
#                                           Street                  SplitPOI  \
# 0       jl kapuk timur delta sili iii lippo cika                        []
# 1                                          siung                        []
# 2                                                             [toko, dita]
# 3                                  jl. orde baru                        []
# 4                                 raya samb gede          [toko, bb, kids]
# ...                                          ...                       ...
# 267998                                kakap raya                        []
# 267999                           jend ahmad yani                        []
# 268000                             raya cila kko                        []
# 268001                                                       [taman, asri]
# 268002                                            [jaya, maspion, permata]
#
#                                               SplitStreet  \
# 0       [jl, kapuk, timur, delta, sili, iii, lippo, cika]
# 1                                                 [siung]
# 2                                                      []
# 3                                       [jl., orde, baru]
# 4                                      [raya, samb, gede]
# ...                                                   ...
# 267998                                      [kakap, raya]
# 267999                                [jend, ahmad, yani]
# 268000                                  [raya, cila, kko]
# 268001                                                 []
# 268002                                                 []
#
#                                                  SplitRaw TransformedPOI  \
# 0       [jl, kapuk, timur, delta, sili, iii, lippo, ci...          False
# 1           [setu, siung, 119, rt, 5, 1, 13880, cipayung]          False
# 2                              [toko, dita, ,, kertosono]          False
# 3                                       [jl., orde, baru]          False
# 4              [raya, samb, gede, ,, 299, toko, bb, kids]          False
# ...                                                   ...            ...
# 267998  [karawaci, baru, kakap, raya, 156, rt, 1, rw, ...          False
# 267999        [jend, ahmad, yani, 331, kertasari, ciamis]          False
# 268000        [raya, cila, kko, ,, cilandak, timur, kel.]          False
# 268001  [jalan, cipadu, jaya, taman, asri, gang, bijak...          False
# 268002  [jaya, maspion, permata, blok, beryl, b2, no, 58]          False
#
#        TransformedStreet                                      clean_address
# 0                  False  jl kapuk timur delta sili iii lippo cika 11 a ...
# 1                  False               setu siung 119 rt 5 1 13880 cipayung
# 2                  False                              toko dita , kertosono
# 3                  False                                      jl. orde baru
# 4                  False                  raya samb gede , 299 toko bb kids
# ...                  ...                                                ...
# 267998             False    karawaci baru kakap raya 156 rt 1 rw 3 karawaci
# 267999             False               jend ahmad yani 331 kertasari ciamis
# 268000             False                raya cila kko , cilandak timur kel.
# 268001             False  jalan cipadu jaya taman asri gang bijaksana 3 ...
# 268002             False           jaya maspion permata blok beryl b2 no 58
#
# [268003 rows x 10 columns]

# %%
processed_df = df[["clean_address", "POI/street"]]
processed_df.rename(columns={"clean_address": "raw_address"}, inplace=True)
processed_df
# Out:
#                                               raw_address  \
# 0       jl kapuk timur delta sili iii lippo cika 11 a ...
# 1                    setu siung 119 rt 5 1 13880 cipayung
# 2                                   toko dita , kertosono
# 3                                           jl. orde baru
# 4                       raya samb gede , 299 toko bb kids
# ...                                                   ...
# 267998    karawaci baru kakap raya 156 rt 1 rw 3 karawaci
# 267999               jend ahmad yani 331 kertasari ciamis
# 268000                raya cila kko , cilandak timur kel.
# 268001  jalan cipadu jaya taman asri gang bijaksana 3 ...
# 268002           jaya maspion permata blok beryl b2 no 58
#
#                                        POI/street
# 0       /jl kapuk timur delta sili iii lippo cika
# 1                                          /siung
# 2                                      toko dita/
# 3                                  /jl. orde baru
# 4                     toko bb kids/raya samb gede
# ...                                           ...
# 267998                                /kakap raya
# 267999                           /jend ahmad yani
# 268000                             /raya cila kko
# 268001                                taman asri/
# 268002                      jaya maspion permata/
#
# [268003 rows x 2 columns]

# %%
processed_df.to_csv(data_dir + "processed_train.csv", index=False)

# %% [markdown]
# ## Create the whole text processing pipeline

# %%
dft = pd.read_csv(data_dir + "test.csv")

# %%
dft["raw_address"] = dft["raw_address"].apply(remove_multiple_whitespace)
dft["raw_address"] = dft["raw_address"].apply(remove_dot)
dft["raw_address"] = dft["raw_address"].apply(remove_comma)
dft["raw_address"] = dft["raw_address"].apply(remove_bracket)

# %%
dft
# Out:
#           id                                        raw_address
# 0          0              s. par 53 sidanegara 4 cilacap tengah
# 1          1             angg per , baloi indah kel. lubuk baja
# 2          2                            asma laun , mand imog ,
# 3          3     ud agung rej , raya nga sri wedari karanganyar
# 4          4                        cut mutia , 35 baiturrahman
# ...      ...                                                ...
# 49995  49995                    toko mbak farid semboro semboro
# 49996  49996   vie - tk. ridho kids , vete 3 cari , 16720 ciawi
# 49997  49997              mart dan roti bakar malabar , nasio ,
# 49998  49998  graha indah pamulang jl. mujair raya bambu apu...
# 49999  49999                                              adi ,
#
# [50000 rows x 2 columns]

# %%
dft.to_csv(data_dir + "processed_test.csv", index=False)
