# %%
import re
from collections import Counter 

import pandas as pd
import numpy as np


import warnings
warnings.filterwarnings('ignore')

# %%
data_dir = "data/"
df = pd.read_csv(data_dir + "processed_train.csv")

# %%
### for testing purpose
# df = df[:2000]

# %%
df
# Out:
#             id                                        raw_address  \
# 0            0  jl kapuk timur delta sili iii lippo cika 11 a ...
# 1            2               setu siung 119 rt 5 1 13880 cipayung
# 2            3                              toko dita , kertosono
# 3            4                                      jl. orde baru
# 4            5                  raya samb gede , 299 toko bb kids
# ...        ...                                                ...
# 265884  299994    karawaci baru kakap raya 156 rt 1 rw 3 karawaci
# 265885  299995               jend ahmad yani 331 kertasari ciamis
# 265886  299996                raya cila kko , cilandak timur kel.
# 265887  299998  jalan cipadu jaya taman asri gang bijaksana 3 ...
# 265888  299999           jaya maspion permata blok beryl b2 no 58
#
#                                        POI/street
# 0       /jl kapuk timur delta sili iii lippo cika
# 1                                          /siung
# 2                                      toko dita/
# 3                                  /jl. orde baru
# 4                     toko bb kids/raya samb gede
# ...                                           ...
# 265884                                /kakap raya
# 265885                           /jend ahmad yani
# 265886                             /raya cila kko
# 265887                                taman asri/
# 265888                      jaya maspion permata/
#
# [265889 rows x 3 columns]

# %%
def getPOI(s) :
    return s.split("/")[0]

def getStreet(s) :
    return s.split("/")[1]

def split(s) :
    s = remove_multiple_whitespace(s)
    return s.split(" ")

# %% [markdown]
# ### Remove whitespace

# %%
# remove multiple whitespace
# cover tabs, newlines, etc
def remove_multiple_whitespace(text) :
    return re.sub(' +', ' ', text.replace('\n', ' ').replace('\t', ' ')).strip()

# %%
remove_multiple_whitespace("asfua asfasbiuf \n \t  asfsa adfgas \t d ")
# Out:
# 'asfua asfasbiuf asfsa adfgas d'

# %%
df["raw_address"] = df["raw_address"].apply(remove_multiple_whitespace)
df["POI/street"] = df["POI/street"].apply(remove_multiple_whitespace)

# %%
df["POI"] = df["POI/street"].apply(getPOI)
df["Street"] = df["POI/street"].apply(getStreet) 

df["SplitRaw"] = df["raw_address"].apply(split)
df["SplitPOI"] = df["POI"].apply(split)
df["SplitStreet"] = df["Street"].apply(split)

df
# Out:
#             id                                        raw_address  \
# 0            0  jl kapuk timur delta sili iii lippo cika 11 a ...
# 1            2               setu siung 119 rt 5 1 13880 cipayung
# 2            3                              toko dita , kertosono
# 3            4                                      jl. orde baru
# 4            5                  raya samb gede , 299 toko bb kids
# ...        ...                                                ...
# 265884  299994    karawaci baru kakap raya 156 rt 1 rw 3 karawaci
# 265885  299995               jend ahmad yani 331 kertasari ciamis
# 265886  299996                raya cila kko , cilandak timur kel.
# 265887  299998  jalan cipadu jaya taman asri gang bijaksana 3 ...
# 265888  299999           jaya maspion permata blok beryl b2 no 58
#
#                                        POI/street                   POI  \
# 0       /jl kapuk timur delta sili iii lippo cika
# 1                                          /siung
# 2                                      toko dita/             toko dita
# 3                                  /jl. orde baru
# 4                     toko bb kids/raya samb gede          toko bb kids
# ...                                           ...                   ...
# 265884                                /kakap raya
# 265885                           /jend ahmad yani
# 265886                             /raya cila kko
# 265887                                taman asri/            taman asri
# 265888                      jaya maspion permata/  jaya maspion permata
#
#                                           Street  \
# 0       jl kapuk timur delta sili iii lippo cika
# 1                                          siung
# 2
# 3                                  jl. orde baru
# 4                                 raya samb gede
# ...                                          ...
# 265884                                kakap raya
# 265885                           jend ahmad yani
# 265886                             raya cila kko
# 265887
# 265888
#
#                                                  SplitRaw  \
# 0       [jl, kapuk, timur, delta, sili, iii, lippo, ci...
# 1           [setu, siung, 119, rt, 5, 1, 13880, cipayung]
# 2                              [toko, dita, ,, kertosono]
# 3                                       [jl., orde, baru]
# 4              [raya, samb, gede, ,, 299, toko, bb, kids]
# ...                                                   ...
# 265884  [karawaci, baru, kakap, raya, 156, rt, 1, rw, ...
# 265885        [jend, ahmad, yani, 331, kertasari, ciamis]
# 265886        [raya, cila, kko, ,, cilandak, timur, kel.]
# 265887  [jalan, cipadu, jaya, taman, asri, gang, bijak...
# 265888  [jaya, maspion, permata, blok, beryl, b2, no, 58]
#
#                         SplitPOI  \
# 0                             []
# 1                             []
# 2                   [toko, dita]
# 3                             []
# 4               [toko, bb, kids]
# ...                          ...
# 265884                        []
# 265885                        []
# 265886                        []
# 265887             [taman, asri]
# 265888  [jaya, maspion, permata]
#
#                                               SplitStreet
# 0       [jl, kapuk, timur, delta, sili, iii, lippo, cika]
# 1                                                 [siung]
# 2                                                      []
# 3                                       [jl., orde, baru]
# 4                                      [raya, samb, gede]
# ...                                                   ...
# 265884                                      [kakap, raya]
# 265885                                [jend, ahmad, yani]
# 265886                                  [raya, cila, kko]
# 265887                                                 []
# 265888                                                 []
#
# [265889 rows x 8 columns]

# %%
def is_transformed(words, sentence): 
    if " ".join(words) in sentence :
        return False
    return True

# %%
words = ["taman", "meruya"]
sentence = "taman mer , 13 electr laun system , 2 meruya utara"
f(words, sentence)
# Out:
# True

# %%
df['TransformedPOI'] = df.apply(lambda x: is_transformed(x.SplitPOI, x.raw_address), axis=1)
df['TransformedStreet'] = df.apply(lambda x: is_transformed(x.SplitStreet, x.raw_address), axis=1)

# %%
df
# Out:
#             id                                        raw_address  \
# 0            0  jl kapuk timur delta sili iii lippo cika 11 a ...
# 1            2               setu siung 119 rt 5 1 13880 cipayung
# 2            3                              toko dita , kertosono
# 3            4                                      jl. orde baru
# 4            5                  raya samb gede , 299 toko bb kids
# ...        ...                                                ...
# 265884  299994    karawaci baru kakap raya 156 rt 1 rw 3 karawaci
# 265885  299995               jend ahmad yani 331 kertasari ciamis
# 265886  299996                raya cila kko , cilandak timur kel.
# 265887  299998  jalan cipadu jaya taman asri gang bijaksana 3 ...
# 265888  299999           jaya maspion permata blok beryl b2 no 58
#
#                                        POI/street                   POI  \
# 0       /jl kapuk timur delta sili iii lippo cika
# 1                                          /siung
# 2                                      toko dita/             toko dita
# 3                                  /jl. orde baru
# 4                     toko bb kids/raya samb gede          toko bb kids
# ...                                           ...                   ...
# 265884                                /kakap raya
# 265885                           /jend ahmad yani
# 265886                             /raya cila kko
# 265887                                taman asri/            taman asri
# 265888                      jaya maspion permata/  jaya maspion permata
#
#                                           Street  \
# 0       jl kapuk timur delta sili iii lippo cika
# 1                                          siung
# 2
# 3                                  jl. orde baru
# 4                                 raya samb gede
# ...                                          ...
# 265884                                kakap raya
# 265885                           jend ahmad yani
# 265886                             raya cila kko
# 265887
# 265888
#
#                                                  SplitRaw  \
# 0       [jl, kapuk, timur, delta, sili, iii, lippo, ci...
# 1           [setu, siung, 119, rt, 5, 1, 13880, cipayung]
# 2                              [toko, dita, ,, kertosono]
# 3                                       [jl., orde, baru]
# 4              [raya, samb, gede, ,, 299, toko, bb, kids]
# ...                                                   ...
# 265884  [karawaci, baru, kakap, raya, 156, rt, 1, rw, ...
# 265885        [jend, ahmad, yani, 331, kertasari, ciamis]
# 265886        [raya, cila, kko, ,, cilandak, timur, kel.]
# 265887  [jalan, cipadu, jaya, taman, asri, gang, bijak...
# 265888  [jaya, maspion, permata, blok, beryl, b2, no, 58]
#
#                         SplitPOI  \
# 0                             []
# 1                             []
# 2                   [toko, dita]
# 3                             []
# 4               [toko, bb, kids]
# ...                          ...
# 265884                        []
# 265885                        []
# 265886                        []
# 265887             [taman, asri]
# 265888  [jaya, maspion, permata]
#
#                                               SplitStreet  TransformedPOI  \
# 0       [jl, kapuk, timur, delta, sili, iii, lippo, cika]           False
# 1                                                 [siung]           False
# 2                                                      []           False
# 3                                       [jl., orde, baru]           False
# 4                                      [raya, samb, gede]           False
# ...                                                   ...             ...
# 265884                                      [kakap, raya]           False
# 265885                                [jend, ahmad, yani]           False
# 265886                                  [raya, cila, kko]           False
# 265887                                                 []           False
# 265888                                                 []           False
#
#         TransformedStreet
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 265884              False
# 265885              False
# 265886              False
# 265887              False
# 265888              False
#
# [265889 rows x 10 columns]

# %% [markdown]
# **Note:**
# there is a corrector for misspell word
#
# words = ['ds.', 'sukowiyono', 'dsn.', 'karangsono', 'rt', '01', 'rw', '03', 'utara', 'jembatan', 'simomasuk', 'gang', 'jembatan']
#
# POI = ['jembatan', 'simo']

# %%
odds = []
def repair_words(words, repaireds, is_transformed) :
    if not is_transformed :
        return [words, []]
    res = words.copy()
    ori = []
    i = 0
    while i < len(words) :
        curr = words[i]
        if curr == repaireds[0][:len(curr)] :
            j = 1
            while j < len(repaireds) :
                if i + j >= len(words) :
                    odds.append({"words": words, "repaireds": repaireds})
                    print(i)
                    print(j)
                    print(words)
                    print(repaireds)
                    return [[],[]]
                curr = words[i+j]
                if curr == repaireds[j][:len(curr)] :
                    j += 1
                else :
                    break
            if j == len(repaireds) :
                ori = list(words[i:i+j])
                res[i:i+j] = repaireds
                return [res, ori]
        i += 1
    return [res, ori]

# %%
def get_index_zero(arr) :
    return arr[0]

def get_index_one(arr) :
    if len(arr) <= 1 :
        print(arr)
    return arr[1]

df["temp"] = df.apply(lambda x : repair_words(x.SplitRaw, x.SplitPOI, x.TransformedPOI), axis=1)
df["cleaned_address"] = df["temp"].apply(get_index_zero)
df["OriPOI"] = df["temp"].apply(get_index_one)
df["temp"] = df.apply(lambda x : repair_words(x.cleaned_address, x.SplitStreet, x.TransformedStreet), axis=1)
df["cleaned_address"] = df["temp"].apply(get_index_zero)
df["OriStreet"] = df["temp"].apply(get_index_one)

# %%
df[df["TransformedPOI"]].head()
# Out:
#     id                                      raw_address  \
# 9   10  cikahuripan sd neg boj 02 klap boj , no 5 16877
# 10  11                                    yaya atohar ,
# 18  20                                  toko bang ajs ,
# 36  40            mar tabl metro iringmulyo metro timur
# 38  44                                sd neg 12 anggrek
#
#                       POI/street                   POI    Street  \
# 9   sd negeri bojong 02/klap boj   sd negeri bojong 02  klap boj
# 10           yayasan atohariyah/    yayasan atohariyah
# 18            toko bangunan ajs/     toko bangunan ajs
# 36         markaz tabligh metro/  markaz tabligh metro
# 38         sd negeri 12 anggrek/  sd negeri 12 anggrek
#
#                                              SplitRaw  \
# 9   [cikahuripan, sd, neg, boj, 02, klap, boj, ,, ...
# 10                                  [yaya, atohar, ,]
# 18                               [toko, bang, ajs, ,]
# 36       [mar, tabl, metro, iringmulyo, metro, timur]
# 38                             [sd, neg, 12, anggrek]
#
#                      SplitPOI  SplitStreet  TransformedPOI  TransformedStreet  \
# 9    [sd, negeri, bojong, 02]  [klap, boj]            True              False
# 10      [yayasan, atohariyah]           []            True              False
# 18      [toko, bangunan, ajs]           []            True              False
# 36   [markaz, tabligh, metro]           []            True              False
# 38  [sd, negeri, 12, anggrek]           []            True              False
#
#                                                  temp  \
# 9   [[cikahuripan, sd, negeri, bojong, 02, klap, b...
# 10                     [[yayasan, atohariyah, ,], []]
# 18                     [[toko, bangunan, ajs, ,], []]
# 36  [[markaz, tabligh, metro, iringmulyo, metro, t...
# 38                    [[sd, negeri, 12, anggrek], []]
#
#                                       cleaned_address                  OriPOI  \
# 9   [cikahuripan, sd, negeri, bojong, 02, klap, bo...      [sd, neg, boj, 02]
# 10                           [yayasan, atohariyah, ,]          [yaya, atohar]
# 18                           [toko, bangunan, ajs, ,]       [toko, bang, ajs]
# 36  [markaz, tabligh, metro, iringmulyo, metro, ti...      [mar, tabl, metro]
# 38                          [sd, negeri, 12, anggrek]  [sd, neg, 12, anggrek]
#
#    OriStreet
# 9         []
# 10        []
# 18        []
# 36        []
# 38        []

# %% [markdown]
# ### Save Cleaned Address

# %%
temp = df[["id", "cleaned_address", "POI/street"]].copy()
temp["cleaned_address"] = temp["cleaned_address"].apply(lambda x : remove_multiple_whitespace(" ".join(x)))
temp
# Out:
#             id                                    cleaned_address  \
# 0            0  jl kapuk timur delta sili iii lippo cika 11 a ...
# 1            2               setu siung 119 rt 5 1 13880 cipayung
# 2            3                              toko dita , kertosono
# 3            4                                      jl. orde baru
# 4            5                  raya samb gede , 299 toko bb kids
# ...        ...                                                ...
# 265884  299994    karawaci baru kakap raya 156 rt 1 rw 3 karawaci
# 265885  299995               jend ahmad yani 331 kertasari ciamis
# 265886  299996                raya cila kko , cilandak timur kel.
# 265887  299998  jalan cipadu jaya taman asri gang bijaksana 3 ...
# 265888  299999           jaya maspion permata blok beryl b2 no 58
#
#                                        POI/street
# 0       /jl kapuk timur delta sili iii lippo cika
# 1                                          /siung
# 2                                      toko dita/
# 3                                  /jl. orde baru
# 4                     toko bb kids/raya samb gede
# ...                                           ...
# 265884                                /kakap raya
# 265885                           /jend ahmad yani
# 265886                             /raya cila kko
# 265887                                taman asri/
# 265888                      jaya maspion permata/
#
# [265889 rows x 3 columns]

# %%
temp.rename(columns={"cleaned_address": "raw_address"}).to_csv("data/cleaned_train.csv", index=False)

# %% [markdown]
# # Create a Probabilistic Model for Word Transformation

# %%
df[["TransformedPOI", "SplitPOI", "OriPOI", "TransformedStreet", "SplitStreet", "OriStreet"]]
# Out:
#         TransformedPOI                  SplitPOI OriPOI  TransformedStreet  \
# 0                False                        []     []              False
# 1                False                        []     []              False
# 2                False              [toko, dita]     []              False
# 3                False                        []     []              False
# 4                False          [toko, bb, kids]     []              False
# ...                ...                       ...    ...                ...
# 265884           False                        []     []              False
# 265885           False                        []     []              False
# 265886           False                        []     []              False
# 265887           False             [taman, asri]     []              False
# 265888           False  [jaya, maspion, permata]     []              False
#
#                                               SplitStreet OriStreet
# 0       [jl, kapuk, timur, delta, sili, iii, lippo, cika]        []
# 1                                                 [siung]        []
# 2                                                      []        []
# 3                                       [jl., orde, baru]        []
# 4                                      [raya, samb, gede]        []
# ...                                                   ...       ...
# 265884                                      [kakap, raya]        []
# 265885                                [jend, ahmad, yani]        []
# 265886                                  [raya, cila, kko]        []
# 265887                                                 []        []
# 265888                                                 []        []
#
# [265889 rows x 6 columns]

# %% [markdown]
# ### List of Transformation

# %%
trans = df[df.apply(lambda x: not (x.TransformedPOI == False and x.TransformedStreet == False), axis=1)]
trans = trans[["TransformedPOI", "SplitPOI", "OriPOI", "TransformedStreet", "SplitStreet", "OriStreet"]]
trans.head()
# Out:
#     TransformedPOI                   SplitPOI                  OriPOI  \
# 9             True   [sd, negeri, bojong, 02]      [sd, neg, boj, 02]
# 10            True      [yayasan, atohariyah]          [yaya, atohar]
# 18            True      [toko, bangunan, ajs]       [toko, bang, ajs]
# 36            True   [markaz, tabligh, metro]      [mar, tabl, metro]
# 38            True  [sd, negeri, 12, anggrek]  [sd, neg, 12, anggrek]
#
#     TransformedStreet  SplitStreet OriStreet
# 9               False  [klap, boj]        []
# 10              False           []        []
# 18              False           []        []
# 36              False           []        []
# 38              False           []        []

# %%
def sort_dict(d) :
    return {k: v for k, v in sorted(d.items(), key=lambda item: item[1], reverse=True)}

# %%
# WORD TRANSFORMATION NEED TO CONSIDER PREVIOUS AND NEXT WORD

# %%
trans.head()
# Out:
#     TransformedPOI                   SplitPOI                  OriPOI  \
# 9             True   [sd, negeri, bojong, 02]      [sd, neg, boj, 02]
# 10            True      [yayasan, atohariyah]          [yaya, atohar]
# 18            True      [toko, bangunan, ajs]       [toko, bang, ajs]
# 36            True   [markaz, tabligh, metro]      [mar, tabl, metro]
# 38            True  [sd, negeri, 12, anggrek]  [sd, neg, 12, anggrek]
#
#     TransformedStreet  SplitStreet OriStreet
# 9               False  [klap, boj]        []
# 10              False           []        []
# 18              False           []        []
# 36              False           []        []
# 38              False           []        []

# %% [markdown]
# ### 1 Word Transformation

# %%
unitransforms = {}

def process_unitransform(unitransforms, is_transformeds, repaireds, originals) :
    for is_transformed, repair, ori in zip(is_transformeds, repaireds, originals) :
        if is_transformed :
            for r, o in zip(repair, ori) :
                if r != o :
                    if o not in unitransforms :
                        unitransforms[o] = {}
                        unitransforms[o][r] = 1
                    else :
                        if r in unitransforms[o] :
                            unitransforms[o][r] += 1
                        else :
                            unitransforms[o][r] = 1

process_unitransform(unitransforms, trans["TransformedPOI"], trans["SplitPOI"], trans["OriPOI"])
process_unitransform(unitransforms, trans["TransformedStreet"], trans["SplitStreet"], trans["OriStreet"])

for k, v in unitransforms.items() :
    unitransforms[k] = sort_dict(v)

# %%
# unitransforms

# %%
unitransforms["cak"]
# Out:
# {'cakung': 15, 'cakruk': 1, "cake's": 1, 'cakery': 1, 'cakrad': 1, 'cakrab': 1}

# %% [markdown]
# ### 2 Word Transformation

# %%
bitransforms = {}

def process_bitransform(bitransforms, is_transformeds, repaireds, originals) :
    for is_transformed, repair, ori in zip(is_transformeds, repaireds, originals) :
        if is_transformed :
            if len(repair) == len(ori) and len(repair) > 1:
                i = 0
                while i < len(repair)-1 :
                    r = repair[i] + " " + repair[i+1]
                    o = ori[i] + " " + ori[i+1]
                    if r != o :
                        if o not in bitransforms :
                            bitransforms[o] = {}
                            bitransforms[o][r] = 1
                        else :
                            if r in bitransforms[o] :
                                bitransforms[o][r] += 1
                            else :
                                bitransforms[o][r] = 1
                    i += 1

process_bitransform(bitransforms, trans["TransformedPOI"], trans["SplitPOI"], trans["OriPOI"])
process_bitransform(bitransforms, trans["TransformedStreet"], trans["SplitStreet"], trans["OriStreet"])

for k, v in bitransforms.items() :
    bitransforms[k] = sort_dict(v)

# %%
bitransforms["taman mer"]
# Out:
# {'taman meruya': 2}

# %%
# bitransforms

# %% [markdown]
# ### 3 Word Transformation

# %%
tritransforms = {}
def process_tritransform(bitransforms, is_transformeds, repaireds, originals) :
    for is_transformed, repair, ori in zip(is_transformeds, repaireds, originals) :
        if is_transformed :
            if len(repair) == len(ori) and len(repair) > 2:
                i = 0
                while i < len(repair)-2 :
                    r = repair[i] + " " + repair[i+1] + " " + repair[i+2]
                    o = ori[i] + " " + ori[i+1] + " " + ori[i+2]
                    if r != o :
                        if o not in tritransforms :
                            tritransforms[o] = {}
                            tritransforms[o][r] = 1
                        else :
                            if r in tritransforms[o] :
                                tritransforms[o][r] += 1
                            else :
                                tritransforms[o][r] = 1
                    i += 1

process_tritransform(tritransforms, trans["TransformedPOI"], trans["SplitPOI"], trans["OriPOI"])
process_tritransform(tritransforms, trans["TransformedStreet"], trans["SplitStreet"], trans["OriStreet"])                
                
for k, v in tritransforms.items() :
    tritransforms[k] = sort_dict(v)

# %%
# tritransforms

# %% [markdown]
# ### 4 Word Transformation

# %%
qtransforms = {}
def process_qtransform(qtransforms, is_transformeds, repaireds, originals) :
    for is_transformed, repair, ori in zip(is_transformeds, repaireds, originals) :
        if is_transformed :
            if len(repair) == len(ori) and len(repair) > 3:
                i = 0
                while i < len(repair)-3 :
                    r = repair[i] + " " + repair[i+1] + " " + repair[i+2] + " " + repair[i+3]
                    o = ori[i] + " " + ori[i+1] + " " + ori[i+2] + " " + ori[i+3]
                    if r != o :
                        if o not in qtransforms :
                            qtransforms[o] = {}
                            qtransforms[o][r] = 1
                        else :
                            if r in qtransforms[o] :
                                qtransforms[o][r] += 1
                            else :
                                qtransforms[o][r] = 1
                    i += 1

process_qtransform(qtransforms, trans["TransformedPOI"], trans["SplitPOI"], trans["OriPOI"])
process_qtransform(qtransforms, trans["TransformedStreet"], trans["SplitStreet"], trans["OriStreet"])                


for k, v in qtransforms.items() :
    qtransforms[k] = sort_dict(v)

# %%
# qtransforms

# %% [markdown]
# # Combine n-grams

# %% [markdown]
# ### Create Unigram

# %%
df = pd.read_csv('data/processed_train.csv')
df.head()
# Out:
#    id                                        raw_address  \
# 0   0  jl kapuk timur delta sili iii lippo cika 11 a ...
# 1   2               setu siung 119 rt 5 1 13880 cipayung
# 2   3                              toko dita , kertosono
# 3   4                                      jl. orde baru
# 4   5                  raya samb gede , 299 toko bb kids
#
#                                   POI/street
# 0  /jl kapuk timur delta sili iii lippo cika
# 1                                     /siung
# 2                                 toko dita/
# 3                             /jl. orde baru
# 4                toko bb kids/raya samb gede

# %%
tokens = []
for s in df["raw_address"] :
    words = s.split(" ")
    for word in words :
        tokens.append(word)
unigrams = Counter(tokens)

# %%
unigrams.most_common()[:10]
# Out:
# [(',', 180846),
#  ('no', 47575),
#  ('rt', 39233),
#  ('raya', 31761),
#  ('1', 21386),
#  ('2', 19532),
#  ('rw', 18853),
#  ('3', 16272),
#  ('4', 13234),
#  ('barat', 13224)]

# %% [markdown]
# ### Create Bigram

# %%
tokens = []
for s in df["raw_address"] :
    words = s.split(" ")
    n = len(words)
    if n > 1 :
        i = 0
        while i < n - 1 : 
            text = words[i] + " " + words[i+1]
            tokens.append(text)
            i += 1 
bigrams = Counter(tokens)

# %%
bigrams.most_common()[:10]
# Out:
# [(', no', 18757),
#  (', raya', 5498),
#  ('rt 1', 5238),
#  ('raya ,', 4590),
#  ('rt 2', 4485),
#  ('rt 3', 4038),
#  ('rt 4', 3538),
#  ('rt 5', 3052),
#  ('rt 6', 2462),
#  ('2 ,', 2239)]

# %% [markdown]
# ### Create Trigram

# %%
tokens = []
for s in df["raw_address"] :
    words = s.split(" ")
    n = len(words)
    if n > 2 :
        i = 0
        while i < n - 2 : 
            text = words[i] + " " + words[i+1] + " " + words[i+2]
            tokens.append(text)
            i += 1 
trigrams = Counter(tokens)

# %%
trigrams.most_common()[:10]
# Out:
# [('rt 1 rw', 1120),
#  ('raya , no', 1020),
#  ('ahmad yani ,', 965),
#  ('rt 2 rw', 940),
#  ('rt 3 rw', 872),
#  ('rt 4 rw', 737),
#  ('jend ahmad yani', 727),
#  ('jend sudi ,', 701),
#  ('rt 5 rw', 655),
#  (', no 1', 600)]

# %% [markdown]
# # Transformation

# %%
def repair_qgram(text) :
    words = text.split(" ")
    n = len(words)
    if n > 3 :
        for i in range(n-3) :
            token = words[i] + " " + words[i+1] + " " + words[i+2] + " " + words[i+3]
            if token in qtransforms :
                text = text.replace(token, list(qtransforms[token])[0])
    return text

repair_qgram(text)
# Out:
# 'b2 no 58'

# %%
trirepair = {}
for k, v in tritransforms.items() :
    words = list(v.keys())
    counts = list(v.values())
    first_word, first_count = words[0], counts[0]
    uncertain = True
    if len(v) > 1 :
        second_word, second_count = words[1], counts[1]
        if first_count > second_count * 2 :
            uncertain = False
    else :
        uncertain = False

    if not uncertain :
        if 1.5 * first_count > trigrams[k] :
            trirepair[k] = first_word

# %%
def repair_trigram(text) :
    words = text.split(" ")
    n = len(words)
    if n > 2 :
        for i in range(n-2) :
            token = words[i] + " " + words[i+1] + " " + words[i+2]
            if token in trirepair :
                text = text.replace(token, trirepair[token])
    return text

text = "cikahuripan sd neg boj 02 klap boj , no 5 16877"
text = "raya samb gede , 299 toko bb kids"
repair_trigram(text)
# Out:
# 'raya samb gede , 299 toko bb kids'

# %%
birepair = {}
for k, v in bitransforms.items() :
    words = list(v.keys())
    counts = list(v.values())
    first_word, first_count = words[0], counts[0]
    uncertain = True
    if len(v) > 1 :
        second_word, second_count = words[1], counts[1]
        if first_count > second_count * 3 :
            uncertain = False
    else :
        uncertain = False

    if not uncertain :
        if 1.5 * first_count > bigrams[k] :
            birepair[k] = first_word

# %%
def repair_bigram(text) :
    words = text.split(" ")
    n = len(words)
    if n > 1 :
        for i in range(n-1) :
            token = words[i] + " " + words[i+1]
            if token in birepair :
                text = text.replace(token, birepair[token])
    return text

text = "cikahuripan sd neg boj 02 klap boj , no 5 16877"
# text = "delta sili"
repair_bigram(text)
# Out:
# 'cikahuripan sd negeri bojong 02 klap boj , no 5 16877'

# %%
unirepair = {}
for k, v in unitransforms.items() :
    words = list(v.keys())
    counts = list(v.values())
    first_word, first_count = words[0], counts[0]

    uncertain = True
    if len(v) > 1 :
        second_word, second_count = words[1], counts[1]
        if first_count > second_count * 10 :
            uncertain = False
    else :
        uncertain = False

    if not uncertain :
        if 1.1 * first_count > unigrams[k]:
            unirepair[k] = first_word

# %%
def repair_unigram(text) :
    words = text.split(" ")
    for i in range(len(words)) :
        if words[i] in unirepair :
            words[i] = unirepair[words[i]]
    return " ".join(words)

text = "cikahuripan sd neg boj 02 klap boj , no 5 16877"
repair_bigram(text)
# Out:
# 'cikahuripan sd negeri bojong 02 klap boj , no 5 16877'

# %%
# unirepair

# %% [markdown]
# ## Debugging for Repair

# %%
def repair_debug(text) : 
    text = repair_qgram(text)
    print("4: ", text)
    text = repair_trigram(text)
    print("3: ", text)
    text = repair_bigram(text)
    print("2: ", text)
#     text = repair_unigram(text)
#     print("1: ", text)
    return text

# %%
text = "jl kapuk timur delta sili iii lippo cika 11 a cicau cikarang pusat" 
# text = "toko sae , tulakan-tegalombo"
# text = "cak 11 nagasari karawang barat"
# text = "raya samb gede , 299 toko bb kids"
text = "beng las listrik rah , raya sorea , cangkuang"
text = "simpang tiga kah nasu no 112 28284 bukit raya"
repair_debug(text)
# Out:
# 4:  simpang tiga kah nasu no 112 28284 bukit raya
# 3:  simpang tiga kah nasu no 112 28284 bukit raya
# 2:  simpang tiga kah nasu no 112 28284 bukit raya
# 'simpang tiga kah nasu no 112 28284 bukit raya'

# %%
bitext = "kah nasu"
# bitext = ""
print(bitransforms[bitext])
print(bigrams[bitext])
# Out:
# {'kaharu nasu': 5}
# 20

# %%
unitext = "cika"
print(unitransforms[unitext])
print(unigrams[unitext])
# Out:
# {'cikarang': 26, 'cikande': 6, 'cikampek': 5, 'cikajang': 4, 'cikalong': 4, 'cikawao': 2, 'cikakak': 1, 'cikanteh': 1, 'cikalang': 1, 'cikadut': 1}
# 381

# %%
text = "raya samb gede"
print(tritransforms[text])
print(trigrams[text])
# Out:
# {'raya sambong gede': 2}
# 13

# %% [markdown]
# # Check Number of Repair with Cleaned Data

# %%
cdf = pd.read_csv('data/cleaned_train.csv')
cdf.head()
# Out:
#    id                                        raw_address  \
# 0   0  jl kapuk timur delta sili iii lippo cika 11 a ...
# 1   2               setu siung 119 rt 5 1 13880 cipayung
# 2   3                              toko dita , kertosono
# 3   4                                      jl. orde baru
# 4   5                  raya samb gede , 299 toko bb kids
#
#                                   POI/street
# 0  /jl kapuk timur delta sili iii lippo cika
# 1                                     /siung
# 2                                 toko dita/
# 3                             /jl. orde baru
# 4                toko bb kids/raya samb gede

# %%
def repair(text) : 
    text = repair_qgram(text)
    text = repair_trigram(text)
    text = repair_bigram(text)
    text = repair_unigram(text)
    return text

# %% [markdown]
# ### Before Repair

# %%
check = df["raw_address"] == cdf["raw_address"]
print("Similarity with Cleaned Data: {:.2f}%".format(100 * sum(check)/len(cdf)))
# Out:
# Similarity with Cleaned Data: 77.84%

# %% [markdown]
# ### After Repair

# %%
df["repaired_address"] = df["raw_address"].apply(repair)
df["cleaned_address"] = cdf["raw_address"]
check = df["repaired_address"] == df["cleaned_address"]
print("Similarity with Cleaned Data: {:.2f}%".format(100 * sum(check)/len(cdf)))
# Out:
# Similarity with Cleaned Data: 92.58%

# %% [markdown]
# ## Apply Transformation To Test Data

# %%
dft = pd.read_csv(data_dir + "processed_test.csv")

# %%
dft["cleaned_address"] = dft["raw_address"].apply(repair)

# %%
dft
# Out:
#           id                                        raw_address  \
# 0          0              s. par 53 sidanegara 4 cilacap tengah
# 1          1             angg per , baloi indah kel. lubuk baja
# 2          2                            asma laun , mand imog ,
# 3          3     ud agung rej , raya nga sri wedari karanganyar
# 4          4                        cut mutia , 35 baiturrahman
# ...      ...                                                ...
# 49995  49995                    toko mbak farid semboro semboro
# 49996  49996   vie - tk. ridho kids , vete 3 cari , 16720 ciawi
# 49997  49997              mart dan roti bakar malabar , nasio ,
# 49998  49998  graha indah pamulang jl. mujair raya bambu apu...
# 49999  49999                                              adi ,
#
#                                          cleaned_address
# 0                  s. par 53 sidanegara 4 cilacap tengah
# 1                 angg per , baloi indah kel. lubuk baja
# 2                             asma laundry , mand imog ,
# 3      ud agung rejeki , raya nga sri wedari karanganyar
# 4                            cut mutia , 35 baiturrahman
# ...                                                  ...
# 49995                    toko mbak farid semboro semboro
# 49996  vienna - tk. ridho kids , vete 3 cari , 16720 ...
# 49997          martabak dan roti bakar malabar , nasio ,
# 49998  graha indah pamulang jl. mujair raya bambu apu...
# 49999                                              adi ,
#
# [50000 rows x 3 columns]

# %%
dft[dft["raw_address"] != dft["cleaned_address"]]
# Out:
#           id                                       raw_address  \
# 2          2                           asma laun , mand imog ,
# 3          3    ud agung rej , raya nga sri wedari karanganyar
# 13        13                      war bakso lata kota waingapu
# 16        16      dimas laun demak , jl tanjung ii , katonsari
# 30        30     lemb bimbi belajar gane opera ahmad yani 19 ,
# ...      ...                                               ...
# 49979  49979               toko mona kayu jati tembilahan hulu
# 49987  49987                                toko suha kap marz
# 49994  49994                            m. tau kandai dua woja
# 49996  49996  vie - tk. ridho kids , vete 3 cari , 16720 ciawi
# 49997  49997             mart dan roti bakar malabar , nasio ,
#
#                                          cleaned_address
# 2                             asma laundry , mand imog ,
# 3      ud agung rejeki , raya nga sri wedari karanganyar
# 13                       warung bakso lata kota waingapu
# 16       dimas laundry demak , jl tanjung ii , katonsari
# 30     lembaga bimbingan belajar ganesha operation ah...
# ...                                                  ...
# 49979            toko monalisa kayu jati tembilahan hulu
# 49987                              toko suhanda kap marz
# 49994                          m. taufiq kandai dua woja
# 49996  vienna - tk. ridho kids , vete 3 cari , 16720 ...
# 49997          martabak dan roti bakar malabar , nasio ,
#
# [4358 rows x 3 columns]

# %%
dft.drop(columns=["raw_address"]).rename(columns={"cleaned_address" : "raw_address"}).to_csv("data/cleaned_test.csv")
