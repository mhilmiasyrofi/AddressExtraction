# %%
import pandas as pd
import numpy as np
from time import time
from collections import Counter
import collections

# natural language processing: n-gram ranking
import re
import unicodedata
import nltk

# %%
df_train = pd.read_csv('data/processed_train.csv')
df_train.head()
# Out:
#                                          raw_address  \
# 0  jl kapuk timur delta sili iii lippo cika 11 a ...
# 1               setu siung 119 rt 5 1 13880 cipayung
# 2                              toko dita , kertosono
# 3                                      jl. orde baru
# 4                  raya samb gede , 299 toko bb kids
#
#                                   POI/street
# 0  /jl kapuk timur delta sili iii lippo cika
# 1                                     /siung
# 2                                 toko dita/
# 3                             /jl. orde baru
# 4                toko bb kids/raya samb gede

# %% [markdown]
# ## Token Counter

# %%
tokens = []
for s in df_train["raw_address"] :
    words = s.split(" ")
    for word in words :
        tokens.append(word)

len(tokens)
# Out:
# 2010583

# %%
count = Counter(tokens)

# %%
count.most_common()[:20]
# Out:
# [(',', 180844),
#  ('no', 47574),
#  ('rt', 39233),
#  ('raya', 31761),
#  ('1', 21385),
#  ('2', 19532),
#  ('rw', 18853),
#  ('3', 16272),
#  ('4', 13234),
#  ('barat', 13224),
#  ('timur', 13057),
#  ('5', 12170),
#  ('utara', 12110),
#  ('kel.', 11115),
#  ('jaya', 11020),
#  ('6', 10509),
#  ('selatan', 10103),
#  ('gg.', 9842),
#  ('jl.', 9706),
#  ('7', 9514)]

# %%
count["mas"]
# Out:
# 5094

# %%
count["bang"]
# Out:
# 399

# %%
count["percet"]
# Out:
# 86

# %%
def getInterest(_list, arr_index):
    return _list[arr_index]

df_train['POI'] = df_train['POI/street'].str.split('/').apply(getInterest, args=(0,))
df_train['street'] = df_train['POI/street'].str.split('/').apply(getInterest, args=(1,))
df_train.head(20)
# Out:
#                                           raw_address  \
# 0   jl kapuk timur delta sili iii lippo cika 11 a ...
# 1                setu siung 119 rt 5 1 13880 cipayung
# 2                               toko dita , kertosono
# 3                                       jl. orde baru
# 4                   raya samb gede , 299 toko bb kids
# 5   kem mel raya , no 4 bojong rawalumbu rt 1 36 r...
# 6                             tela keuramat kuta alam
# 7                               gg. i wates magersari
# 8                                    bunga ncole ix 2
# 9     cikahuripan sd neg boj 02 klap boj , no 5 16877
# 10                                      yaya atohar ,
# 11                                       abim ix 24 5
# 12                                  gang xiii rungkut
# 13  kampung gudang areng , desa:anyer , kecamatan:...
# 14           maru baru 2 18 marunda rt 13 3 cilincing
# 15  pangkalan lareh kel ikurkoto koto panjang kec ...
# 16     tanah sereal pekap raya 5 rt 9 4 11210 tambora
# 17                      tam tama barat v , banyumanik
# 18                                    toko bang ajs ,
# 19                                 stadion kobelete ,
#
#                                    POI/street                  POI  \
# 0   /jl kapuk timur delta sili iii lippo cika
# 1                                      /siung
# 2                                  toko dita/            toko dita
# 3                              /jl. orde baru
# 4                 toko bb kids/raya samb gede         toko bb kids
# 5                               /kem mel raya
# 6                                       /tela
# 7                                      /gg. i
# 8                             /bunga ncole ix
# 9                sd negeri bojong 02/klap boj  sd negeri bojong 02
# 10                        yayasan atohariyah/   yayasan atohariyah
# 11                                   /abim ix
# 12                                 /gang xiii
# 13                              gudang areng/         gudang areng
# 14                               /maru baru 2
# 15                           pangkalan lareh/      pangkalan lareh
# 16                                /pekap raya
# 17                          /tam tama barat v
# 18                         toko bangunan ajs/    toko bangunan ajs
# 19                          stadion kobelete/     stadion kobelete
#
#                                       street
# 0   jl kapuk timur delta sili iii lippo cika
# 1                                      siung
# 2
# 3                              jl. orde baru
# 4                             raya samb gede
# 5                               kem mel raya
# 6                                       tela
# 7                                      gg. i
# 8                             bunga ncole ix
# 9                                   klap boj
# 10
# 11                                   abim ix
# 12                                 gang xiii
# 13
# 14                               maru baru 2
# 15
# 16                                pekap raya
# 17                          tam tama barat v
# 18
# 19

# %%
def getListOfWords(sentence):
    sentence = sentence.replace('\n', ' ').replace('\t', ' ')
    sentence = sentence.replace('/', ' ').replace('.', ' ').replace(',', ' ')
    words = sentence.split(' ')
    while '' in words:
        words.remove('')
        
    return [word for word in words if len(words) > 0]

# %%
def getDifference(row):
    raw = getListOfWords(row['raw_address'])
    poi_street = getListOfWords(row['POI/street'])
    temp = set(raw)
    output = [x for x in poi_street if x not in temp]
    if len(output) > 0:
        return output
    else:
        return np.nan

# %%
start = time()

df_train['delta_words'] = df_train.apply(getDifference, axis=1)

print("Executed in {} seconds.".format(time() - start))
# Out:
# Executed in 11.115409135818481 seconds.

# %%
df_need_repair = df_train.dropna()
df_need_repair
# Out:
#                                             raw_address  \
# 9       cikahuripan sd neg boj 02 klap boj , no 5 16877
# 10                                        yaya atohar ,
# 18                                      toko bang ajs ,
# 36                mar tabl metro iringmulyo metro timur
# 38                                    sd neg 12 anggrek
# ...                                                 ...
# 265866                                 moha toha no 167
# 265867   islamic training cen pare , brawi , pelem pare
# 265873       la banda minima , cile raya , pesanggrahan
# 265875                             ginzi cafe , siliw ,
# 265879                             ver , durian bajenis
#
#                                 POI/street                           POI  \
# 9             sd negeri bojong 02/klap boj           sd negeri bojong 02
# 10                     yayasan atohariyah/            yayasan atohariyah
# 18                      toko bangunan ajs/             toko bangunan ajs
# 36                   markaz tabligh metro/          markaz tabligh metro
# 38                   sd negeri 12 anggrek/          sd negeri 12 anggrek
# ...                                    ...                           ...
# 265866                      /mohammad toha
# 265867  islamic training center pare/brawi  islamic training center pare
# 265873       la banda minimarket/cile raya           la banda minimarket
# 265875                ginzi cafe/siliwangi                    ginzi cafe
# 265879                             veruna/                        veruna
#
#                street            delta_words
# 9            klap boj       [negeri, bojong]
# 10                     [yayasan, atohariyah]
# 18                                [bangunan]
# 36                         [markaz, tabligh]
# 38                                  [negeri]
# ...               ...                    ...
# 265866  mohammad toha             [mohammad]
# 265867          brawi               [center]
# 265873      cile raya           [minimarket]
# 265875      siliwangi            [siliwangi]
# 265879                              [veruna]
#
# [56943 rows x 5 columns]

# %% [markdown]
# # N-gram analysis

# %% [markdown]
# ## find the pair

# %%
def getDistance(str1, str2):
    return nltk.edit_distance(str1, str2)

getDistance('negeri', 'neg')
# Out:
# 3

# %%
for ngram in nltk.ngrams(getListOfWords("cikahuripan sd neg boj 02 klap boj, no 5 16877"), 2):
    print (' '.join(ngram))
# Out:
# cikahuripan sd
# sd neg
# neg boj
# boj 02
# 02 klap
# klap boj
# boj no
# no 5
# 5 16877

# %%
x = {1: 2, 3: 4, 4: 3, 2: 1, 0: 0}
sorted_x = sorted(x.items(), key=lambda kv: kv[1])
sorted_dict = collections.OrderedDict(sorted_x)
sorted_x[1][0]
# Out:
# 2

# %%
def getPair(row):
    raw = row['raw_address']
    repaired = row['delta_words']
    _dict1 = {}
    _dict2 = {}
    for repaired_word in repaired:
        for raw_word in getListOfWords(raw):
            _dict2[raw_word] = getDistance(repaired_word, raw_word)
        # get minimum distance word
        sorted_dict2 = sorted(_dict2.items(), key=lambda kv: kv[1])
        _dict1[repaired_word] = sorted_dict2[0][0]
        # inverse dict from raw to repaired
        inv_map = {v: k for k, v in _dict1.items()}
    return inv_map

# %%
df_need_repair['Pair'] = df_need_repair.apply(getPair, axis=1)
df_need_repair
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                             raw_address  \
# 9       cikahuripan sd neg boj 02 klap boj , no 5 16877
# 10                                        yaya atohar ,
# 18                                      toko bang ajs ,
# 36                mar tabl metro iringmulyo metro timur
# 38                                    sd neg 12 anggrek
# ...                                                 ...
# 265866                                 moha toha no 167
# 265867   islamic training cen pare , brawi , pelem pare
# 265873       la banda minima , cile raya , pesanggrahan
# 265875                             ginzi cafe , siliw ,
# 265879                             ver , durian bajenis
#
#                                 POI/street                           POI  \
# 9             sd negeri bojong 02/klap boj           sd negeri bojong 02
# 10                     yayasan atohariyah/            yayasan atohariyah
# 18                      toko bangunan ajs/             toko bangunan ajs
# 36                   markaz tabligh metro/          markaz tabligh metro
# 38                   sd negeri 12 anggrek/          sd negeri 12 anggrek
# ...                                    ...                           ...
# 265866                      /mohammad toha
# 265867  islamic training center pare/brawi  islamic training center pare
# 265873       la banda minimarket/cile raya           la banda minimarket
# 265875                ginzi cafe/siliwangi                    ginzi cafe
# 265879                             veruna/                        veruna
#
#                street            delta_words  \
# 9            klap boj       [negeri, bojong]
# 10                     [yayasan, atohariyah]
# 18                                [bangunan]
# 36                         [markaz, tabligh]
# 38                                  [negeri]
# ...               ...                    ...
# 265866  mohammad toha             [mohammad]
# 265867          brawi               [center]
# 265873      cile raya           [minimarket]
# 265875      siliwangi            [siliwangi]
# 265879                              [veruna]
#
#                                                Pair
# 9                {'neg': 'negeri', 'boj': 'bojong'}
# 10      {'yaya': 'yayasan', 'atohar': 'atohariyah'}
# 18                             {'bang': 'bangunan'}
# 36             {'mar': 'markaz', 'tabl': 'tabligh'}
# 38                                {'neg': 'negeri'}
# ...                                             ...
# 265866                         {'moha': 'mohammad'}
# 265867                            {'cen': 'center'}
# 265873                     {'minima': 'minimarket'}
# 265875                       {'siliw': 'siliwangi'}
# 265879                            {'ver': 'veruna'}
#
# [56943 rows x 6 columns]

# %%
corpus = []
for index, row in df_need_repair.iterrows():
    for key, value in row['Pair'].items():
        temp = [key,value]
        corpus.append(temp)
corpus = Counter(tuple(item) for item in corpus)
corpus = dict(sorted(corpus.items(), key=lambda item: item[1], reverse=True))

# %%
x = {}
x['a'] = [{'abc': 190}]
x['a'].append({'abd': 100})

# %%
if 'b' in x:
    x['b'].append({'bcd': 300})
else:
    x['b'] = [{'bcd': 300}]
x
# Out:
# {'a': [{'abc': 190}, {'abd': 100}], 'b': [{'bcd': 300}]}

# %%
dict_1gram = {}
for key, value in corpus.items():
    if key[0] in dict_1gram:
        dict_1gram[key[0]].append({key[1]: value})
    else:
        dict_1gram[key[0]] = [{key[1]: value}]
# dict_1gram

# %%
small_dict = {}

# %%
for k, v in dict_1gram.items() :
#     print(k)
#     print(v[0])
#     print(list(v[0].items()))
    first_word, first_count = list(v[0].items())[0]
    uncertain = True
    if len(v) > 1 :
        second_word, second_count = list(v[1].items())[0]
        if first_count < second_count * 5 :
            uncertain = False
    else :
        uncertain = False
        
    
    if not uncertain :
        if count[k] < 2 * first_count :
            small_dict[k] = first_word
    
    #     if count[k] < 2 * v[0].

# %%
small_dict
# Out:
# {'indon': 'indonesia',
#  'apo': 'apotek',
#  'pendid': 'pendidikan',
#  'cah': 'cahaya',
#  'yaya': 'yayasan',
#  'kelon': 'kelontong',
#  'kabup': 'kabupaten',
#  'percet': 'percetakan',
#  'nota': 'notaris',
#  'seder': 'sederhana',
#  'ist': 'istana',
#  'muhamma': 'muhammadiyah',
#  'sch': 'school',
#  'lese': 'lesehan',
#  'pegad': 'pegadaian',
#  'barber': 'barbershop',
#  'seaf': 'seafood',
#  'ibtida': 'ibtidaiyah',
#  'dae': 'daerah',
#  'kecam': 'kecamatan',
#  'saud': 'saudara',
#  'pemak': 'pemakaman',
#  'interna': 'international',
#  'wedd': 'wedding',
#  'asur': 'asuransi',
#  'berm': 'bermain',
#  'al-hid': 'al-hidayah',
#  'off': 'office',
#  'cemer': 'cemerlang',
#  'bukal': 'bukalapak',
#  'electr': 'electronic',
#  'kato': 'katolik',
#  'onl': 'online',
#  'kitc': 'kitchen',
#  'masyar': 'masyarakat',
#  'text': 'textile',
#  'tsanaw': 'tsanawiyah',
#  'kuli': 'kuliner',
#  'asu': 'asuhan',
#  'stat': 'station',
#  'pengin': 'penginapan',
#  'univer': 'universitas',
#  'educa': 'education',
#  'paka': 'pakaian',
#  'advert': 'advertising',
#  'organ': 'organizer',
#  'yogyak': 'yogyakarta',
#  'alumi': 'aluminium',
#  'bimbi': 'bimbingan',
#  'kosm': 'kosmetik',
#  'swal': 'swalayan',
#  'baiturr': 'baiturrahman',
#  'souv': 'souvenir',
#  'ols': 'olshop',
#  'out': 'outlet',
#  'pengob': 'pengobatan',
#  'colec': 'colection',
#  'fort': 'fortuna',
#  'engl': 'english',
#  'pimp': 'pimpinan',
#  'lont': 'lontong',
#  'perpust': 'perpustakaan',
#  'bersau': 'bersaudara',
#  'sys': 'system',
#  'adven': 'adventure',
#  'spesi': 'spesialis',
#  'handp': 'handphone',
#  'konsu': 'konsultan',
#  'pets': 'petshop',
#  'lingku': 'lingkungan',
#  'jil': 'jilbab',
#  'sio': 'siomay',
#  'fact': 'factory',
#  'alumu': 'alumunium',
#  'logis': 'logistics',
#  'uru': 'urusan',
#  'mayb': 'maybank',
#  'work': 'workshop',
#  'perwak': 'perwakilan',
#  'wila': 'wilayah',
#  'petern': 'peternakan',
#  'nugr': 'nugraha',
#  'tose': 'toserba',
#  'minima': 'minimarket',
#  'nyo': 'nyoman',
#  'insur': 'insurance',
#  'warm': 'warmindo',
#  'spo': 'sports',
#  'buko': 'bukopin',
#  'fitn': 'fitness',
#  'nik': 'nikmat',
#  'pergu': 'perguruan',
#  'sektret': 'sektretariat',
#  'grap': 'grapari',
#  'khu': 'khusus',
#  'dap': 'dapoer',
#  'sejaht': 'sejahtera',
#  'fird': 'firdaus',
#  'gyp': 'gypsum',
#  'pemeri': 'pemerintah',
#  'akad': 'akademi',
#  'logi': 'logistik',
#  'easy': 'easypay',
#  'perhi': 'perhiasan',
#  'pemanc': 'pemancingan',
#  'ekon': 'ekonomi',
#  'tradis': 'tradisional',
#  'consul': 'consultant',
#  'leat': 'leather',
#  'pantek': 'pantekosta',
#  'perkre': 'perkreditan',
#  'cutt': 'cutting',
#  'insti': 'institute',
#  'commu': 'community',
#  'cosm': 'cosmetic',
#  'purwok': 'purwokerto',
#  'perhu': 'perhutani',
#  'natu': 'natural',
#  'dirgan': 'dirgantara',
#  'al-muha': 'al-muhajirin',
#  'al-bar': 'al-barokah',
#  'komun': 'komunitas',
#  'acceso': 'accesories',
#  'perhub': 'perhubungan',
#  'tenggu': 'tenggumung',
#  "ma'a": "ma'arif",
#  'prote': 'protestan',
#  'opera': 'operation',
#  'an-': 'an-nur',
#  'pemberd': 'pemberdayaan',
#  'aesth': 'aesthetic',
#  'telko': 'telkomsel',
#  'krea': 'kreatif',
#  'salaf': 'salafiyah',
#  'kemakm': 'kemakmuran',
#  'tasikm': 'tasikmalaya',
#  'knal': 'knalpot',
#  'darmaw': 'darmawangsa',
#  'nuruss': 'nurussalam',
#  'faku': 'fakultas',
#  'wallp': 'wallpaper',
#  'telekomu': 'telekomunikasi',
#  'banyuw': 'banyuwangi',
#  'outd': 'outdoor',
#  'kebid': 'kebidanan',
#  'kemena': 'kemenangan',
#  'raudl': 'raudlatul',
#  'brow': 'brownies',
#  'perleng': 'perlengkapan',
#  'superm': 'supermarket',
#  'sorola': 'sorolangun',
#  'indust': 'industries',
#  'roe': 'roemah',
#  'mine': 'mineral',
#  'goy': 'goyang',
#  'unive': 'universal',
#  "mu'm": "mu'minin",
#  'kependu': 'kependudukan',
#  'multifi': 'multifinance',
#  'konstr': 'konstruksi',
#  'netw': 'network',
#  'pergud': 'pergudangan',
#  'penju': 'penjualan',
#  'latume': 'latumenten',
#  'prasm': 'prasmanan',
#  'stoc': 'stockist',
#  'holi': 'holiday',
#  'kontra': 'kontraktor',
#  'strawb': 'strawberry',
#  'probol': 'probolinggo',
#  'mahas': 'mahasiswa',
#  'boar': 'boarding',
#  'shol': 'sholihin',
#  'starb': 'starbucks',
#  'uswa': 'uswatun',
#  'rep': 'repair',
#  'aqi': 'aqiqah',
#  'supp': 'supplier',
#  'elemen': 'elementary',
#  "ta'": "ta'lim",
#  'holl': 'holland',
#  'taic': 'taichan',
#  'perindu': 'perindustrian',
#  'parahy': 'parahyangan',
#  'spec': 'special',
#  'kebers': 'kebersihan',
#  'penge': 'pengelola',
#  'tekh': 'tekhnik',
#  'kecant': 'kecantikan',
#  'liv': 'living',
#  'internat': 'international',
#  'peral': 'peralatan',
#  'ingg': 'inggris',
#  'pengemb': 'pengembangan',
#  'associ': 'associates',
#  'asos': 'asosiasi',
#  'kanak-': 'kanak-kanak',
#  'penyul': 'penyuluhan',
#  'fatahi': 'fatahillah',
#  'gram': 'gramedia',
#  'oleh-': 'oleh-oleh',
#  'equip': 'equipment',
#  'magela': 'magelang-yo',
#  'rekl': 'reklame',
#  'pind': 'pindang',
#  'pekalo': 'pekalongan',
#  'armina': 'arminareka',
#  'blamba': 'blambangan',
#  'kepega': 'kepegawaian',
#  'ekspe': 'ekspedisi',
#  'bumipu': 'bumiputera',
#  'khi': 'khitan',
#  'multim': 'multimedia',
#  'safi': 'safitri',
#  'pertamb': 'pertambangan',
#  'carw': 'carwash',
#  'mukhl': 'mukhlisin',
#  'execu': 'executive',
#  'kepahy': 'kepahyang-',
#  'padep': 'padepokan',
#  'sangku': 'sangkuriang',
#  'makm': 'makmur',
#  'guesth': 'guesthouse',
#  'xpr': 'xpress',
#  'lear': 'learning',
#  'robb': 'robbins',
#  'goron': 'gorontalo',
#  'ligh': 'lighting',
#  'rain': 'rainbow',
#  'pruden': 'prudential',
#  'kebak': 'kebakaran',
#  'teks': 'tekstil',
#  'mos': 'moslem',
#  'cikaja': 'cikajang-c',
#  'alqu': 'alquran',
#  'ruma': 'rumahan',
#  'sabili': 'sabilillah',
#  'perlind': 'perlindungan',
#  'kesejah': 'kesejahteraan',
#  'cappu': 'cappucino',
#  'exclu': 'exclusive',
#  'cemi': 'cemilan',
#  'redd': 'reddoorz',
#  'wada': 'wadasli',
#  'contra': 'contractor',
#  'nyok': 'nyoklat',
#  'profess': 'professional',
#  'menj': 'menjahit',
#  'demok': 'demokrasi',
#  'wareh': 'warehouse',
#  'majale': 'majalengka',
#  'atf': 'atfhal',
#  'capi': 'capital',
#  '"jl': 'jl',
#  'fede': 'federal',
#  'genera': 'generation',
#  'singga': 'singgalang',
#  'khod': 'khodijah',
#  'gapo': 'gapoktan',
#  'polikl': 'poliklinik',
#  'vegeta': 'vegetarian',
#  'adminis': 'administrasi',
#  'authe': 'authentic',
#  'aparte': 'apartement',
#  'nurha': 'nurhayati',
#  'nau': 'naufal',
#  'hosp': 'hospital',
#  'purbal': 'purbalingga',
#  'dou': 'double',
#  'eraf': 'erafone',
#  'eksp': 'ekspress',
#  'palangk': 'palangkaraya',
#  'efe': 'efendi',
#  'pencu': 'pencucian',
#  'dhu': 'dhuafa',
#  'komu': 'komunika',
#  'offi': 'official',
#  'polite': 'politeknik',
#  'conven': 'convention',
#  'taf': 'tafsir',
#  'kinc': 'kinclong',
#  'gado-': 'gado-gado',
#  'inst': 'institut',
#  'modifi': 'modifikasi',
#  'petrok': 'petrokimia',
#  'cham': 'champion',
#  'machi': 'machinery',
#  'puspit': 'puspitasari',
#  'masyi': 'masyithoh',
#  'nitr': 'nitrogen',
#  'mcdona': "mcdonald's",
#  'acad': 'academy',
#  'fir': 'firman',
#  'kunin': 'kuningan-',
#  'penit': 'penitipan',
#  'vint': 'vintage',
#  'tahf': 'tahfidz',
#  'profes': 'profesional',
#  'perad': 'peradaban',
#  'komuni': 'komunikasi',
#  'perjal': 'perjalanan',
#  'cott': 'cottage',
#  'cemerl': 'cemerlang',
#  'roudl': 'roudlotul',
#  'doors': 'doorsmeer',
#  'taekw': 'taekwondo',
#  'ece': 'eceran',
#  'prom': 'promosi',
#  'reflex': 'reflexology',
#  'brot': 'brothers',
#  'kepul': 'kepulauan',
#  'mubar': 'mubarokah',
#  'filade': 'filadelfia',
#  'sugihw': 'sugihwaras',
#  'stok': 'stokist',
#  'insta': 'instalasi',
#  'jewel': 'jewellery',
#  'demo': 'demokrat',
#  'syne': 'synergy',
#  'metropo': 'metropolitan',
#  'sijun': 'sijunjung',
#  'indepe': 'independent',
#  'fest': 'festival',
#  'qual': 'quality',
#  'iskanda': 'iskandarmuda',
#  'tupper': 'tupperware',
#  'infor': 'informasi',
#  'badmi': 'badminton',
#  'driv': 'driving',
#  'brill': 'brilliant',
#  'kuci': 'kucingan',
#  'cus': 'custom',
#  'pensi': 'pensiunan',
#  'foodc': 'foodcourt',
#  'khus': 'khusnul',
#  'perfu': 'perfumery',
#  'pamun': 'pamungkas',
#  'yay': 'yayang',
#  'vent': 'ventura',
#  'imma': 'immanuel',
#  'sekert': 'sekertariat',
#  'metho': 'methodist',
#  'mubta': 'mubtadiin',
#  'tradit': 'traditional',
#  'archite': 'architecture',
#  'sust': 'susteran',
#  'develo': 'development',
#  'penanggu': 'penanggulangan',
#  'hend': 'hendrik',
#  'al-muja': 'al-mujahidin',
#  'shaf': 'shafira',
#  'noo': 'noodle',
#  'waf': 'waffle',
#  'pembia': 'pembiayaan',
#  'jatin': 'jatinom-b',
#  'gasi': 'gasindo',
#  'ort': 'ortega',
#  'flow': 'flowers',
#  'swam': 'swamitra',
#  'fant': 'fantasi',
#  'pelam': 'pelaminan',
#  'orie': 'oriental',
#  'xamt': 'xamthone',
#  'pembay': 'pembayaran',
#  'muhama': 'muhamadiyah',
#  't-sh': 't-shirt',
#  'az-z': 'az-zahra',
#  'adr': 'adrian',
#  'peraw': 'perawatan',
#  'cileungsi-': 'cileungsi-jonggol',
#  'perhim': 'perhimpunan',
#  'gotr': 'gotri-w',
#  'pakual': 'pakualaman',
#  'binam': 'binamarga',
#  'inde': 'indekost',
#  'perbenda': 'perbendaharaan',
#  'kill': 'killiney',
#  'pemasyar': 'pemasyarakatan',
#  'cult': 'culture',
#  'rosd': 'rosdiana',
#  'minim': 'minimalis',
#  'kegi': 'kegiatan',
#  'alfaria': '(alfamart)',
#  'vinc': 'vincent',
#  'darutt': 'daruttaqwa',
#  'daf': 'daftar',
#  'alat-': 'alat-alat',
#  'succ': 'success',
#  'kateru': 'katerungan',
#  'anwa': 'anwarul',
#  'beren': 'berencana',
#  'scoo': 'scooter',
#  'transmi': 'transmigrasi',
#  'pertuk': 'pertukangan',
#  'keswad': 'keswadayaan',
#  'soc': 'soccer',
#  'marb': 'marbella',
#  'screenpr': 'screenprinting',
#  'priv': 'private',
#  'quan': 'quantum',
#  'darussa': "darussa'adah",
#  'lev': "levi's",
#  'kalikep': 'kalikepiting',
#  'ital': 'italian',
#  'maem': 'maemunah',
#  'devel': 'developer',
#  'keuc': 'keuchik',
#  'roas': 'roaster',
#  'hear': 'hearing',
#  'exha': 'exhaust',
#  'karangpa': 'karangpandan-n',
#  'delic': 'delicious',
#  'alki': 'alkitab',
#  'sawungg': 'sawunggaling',
#  'sulisty': 'sulistyowati',
#  'davi': 'davinci',
#  'libe': 'liberty',
#  'perkan': 'perkantoran',
#  'dime': 'dimensi',
#  'yel': 'yellow',
#  'singka': 'singkawang',
#  'paym': 'payment',
#  'pelak': 'pelaksana',
#  'bone-s': 'bone-sinjai',
#  'mercha': 'merchandise',
#  'majala': 'majalaya-ci',
#  'soko-r': 'soko-rengel',
#  'ngadine': 'ngadinegaran',
#  'furnis': 'furnishings',
#  'janu': 'januari',
#  'petuka': 'petukangan',
#  'mutaal': 'mutaalimin',
#  'webs': 'website',
#  'liana': 'lianawati',
#  'vero': 'veronica',
#  'manb': 'manbaul',
#  'playgr': 'playground',
#  'kurni': 'kurniawan',
#  'fifo': 'fiforlif',
#  'nati': 'national',
#  'rusu': 'rusunawa',
#  '"pondok': 'pondok',
#  'pengend': 'pengendalian',
#  'transpor': 'transportation',
#  'direkt': 'direktorat',
#  'pha': 'pharma',
#  'sunr': 'sunrise',
#  'rok': 'rokhim',
#  'konser': 'konservasi',
#  'chap': 'chapter',
#  'gentl': 'gentleman',
#  'dess': 'dessert',
#  'nurhid': 'nurhidayah',
#  'pemec': 'pemecutan',
#  'prior': 'prioritas',
#  'abulya': 'abulyatama',
#  'trai': 'training',
#  'cosme': 'cosmetics',
#  'playg': 'playgroup',
#  'adva': 'advance',
#  'equ': 'equity',
#  'perab': 'perabotan',
#  'commer': 'commercial',
#  'langen': 'langensari',
#  'dete': 'detergen',
#  'watc': 'watches',
#  'misb': 'misbahul',
#  'versai': 'versailles',
#  'nda': 'ndalem',
#  'perem': 'perempuan',
#  'pentak': 'pentakosta',
#  'al-ikh': 'al-ikhlash',
#  'muhamm': 'muhammadyah',
#  'roud': 'roudotul',
#  'acces': 'accesoris',
#  'sudr': 'sudrajat',
#  'taz': 'tazkia',
#  'wasi': 'wasilah',
#  'percon': 'percontohan',
#  'al-has': 'al-hasanah',
#  'perhot': 'perhotelan',
#  'taraka': 'tarakanita',
#  'khatuli': 'khatulistiwa',
#  'manung': 'manunggal',
#  'choi': 'choirul',
#  'welc': 'welcome',
#  'pengr': 'pengrajin',
#  'sucof': 'sucofindo',
#  'lubukli': 'lubuklinggau',
#  'futu': 'futures',
#  'kwar': 'kwartir',
#  'ikht': 'ikhtiar',
#  'solus': 'solusindo',
#  'educat': 'educational',
#  'bering': 'beringharjo',
#  'handic': 'handicraft',
#  'rabo': 'rabobank',
#  'inves': 'investama',
#  'drum': 'drumband',
#  'organi': 'organisasi',
#  'anin': 'anindya',
#  'tongkr': 'tongkrongan',
#  'payaku': 'payakumbuh',
#  'cinder': 'cinderella',
#  'morn': 'morning',
#  'jatinom-b': 'jatinom-boyolali',
#  'tarb': 'tarbiyah',
#  'communi': 'communication',
#  'manage': 'management',
#  'tuban-g': 'tuban-gresik',
#  'transpo': 'transportasi',
#  'priy': 'priyono',
#  'ngenta': 'ngentak-ka',
#  'promos': 'promosindo',
#  'serang-': 'serang-petir',
#  'hutab': 'hutabarat',
#  'hyper': 'hypermart',
#  'regi': 'regional',
#  'perkem': 'perkemahan',
#  'exo': 'exotic',
#  'ekkl': 'ekklesia',
#  'pembu': 'pembuatan',
#  'candim': 'candimulyo',
#  'barbersh': 'barbershopshop',
#  'sanggr': 'sanggrahan',
#  'wele': 'weleri-',
#  'metrop': 'metropolis',
#  'airl': 'airlines',
#  'ande': 'andesta',
#  'akupu': 'akupuntur',
#  'peneli': 'penelitian',
#  'trav': 'travel',
#  'jann': 'jannatul',
#  'puy': 'puyung',
#  'darunn': 'darunnajah',
#  'pemusyaw': 'pemusyawaratan',
#  'tsh': 'tshirt',
#  'susila': 'susilawati',
#  'trengg': 'trenggalek',
#  'al-am': 'al-amanah',
#  'al-muba': 'al-mubarokah',
#  'reje': 'rejeki',
#  'thor': 'thoriqul',
#  'mukarr': 'mukarromah',
#  'blos': 'blossom',
#  'pengel': 'pengelolaan',
#  'fifg': 'fifgroup',
#  'jayawi': 'jayawijaya',
#  'prabumu': 'prabumulih-b',
#  'pudd': 'pudding',
#  'kall': 'kallista',
#  'spi': 'spirit',
#  'rut': 'ruteng',
#  'tebui': 'tebuireng',
#  'alhamdu': 'alhamdulillah',
#  'eraw': 'erawati',
#  'siswomi': 'siswomiharjo',
#  'zam-': 'zam-zam',
#  'kosw': 'koswara',
#  'safr': 'safrudin',
#  'hyun': 'hyundai',
#  'recor': 'recording',
#  'mutma': 'mutmainah',
#  'karawang-p': 'karawang-pamanukan',
#  'huri': 'huriyah',
#  'muaw': 'muawanah',
#  'outb': 'outbound',
#  'cae': 'caesar',
#  'plyw': 'plywood',
#  'karo-p': 'karo-panji',
#  '7-el': '7-eleven',
#  'mancak-': 'mancak-anyer',
#  'arb': 'arbain',
#  'glob': 'global',
#  'mome': 'momentum',
#  'dinam': 'dinamika',
#  'spl': 'splash',
#  'tual': 'tualang',
#  'pengir': 'pengiriman',
#  'flex': 'flexible',
#  'founda': 'foundation',
#  'surtik': 'surtikanti',
#  'ketenagak': 'ketenagakerjaan',
#  'kaml': 'kamling',
#  'photow': 'photoworks',
#  'dimen': 'dimension',
#  'buah-b': 'buah-buahan',
#  'chata': 'chatarina',
#  'tazm': 'tazmania',
#  'jad': 'jadoel',
#  'madinatu': 'madinatunnajah',
#  'zulkar': 'zulkarnain',
#  'pujungan-pupu': 'pujungan-pupuan-tabanan',
#  'revolu': 'revolution',
#  'cynt': 'cynthia',
#  'sento': 'sentolo-m',
#  'bedugu': 'bedugul-si',
#  'inje': 'injeksi',
#  'peker': 'pekerjaan',
#  'padjad': 'padjadjaran',
#  'vert': 'vertikal',
#  'getse': 'getsemani',
#  'buluta': 'bulutangkis',
#  'atam': 'atambua',
#  'jail': 'jailani',
#  'kiansa': 'kiansantang',
#  'cakrab': 'cakrabuana',
#  'publis': 'publishing',
#  'garmen': 'garmentama',
#  'pengol': 'pengolahan',
#  'al-kha': 'al-khairaat',
#  'broth': 'brothers',
#  'maim': 'maimbau',
#  'swim': 'swimming',
#  'klad': 'klademak',
#  'wanabh': 'wanabhakti',
#  'darw': 'darwati',
#  'gui': 'guitar',
#  'telekomun': 'telekomunikasi',
#  'samaf': 'samafitro',
#  'kutoarjo-': 'kutoarjo-kebumen',
#  'sprin': 'springbed',
#  'asseco': 'assecories',
#  'syaifu': 'syaifullah',
#  'panine': 'panineungan',
#  'amoo': 'amoorea',
#  'detai': 'detailing',
#  'frei': 'freight',
#  'automo': 'automotive',
#  'basm': 'basmalah',
#  'sugiy': 'sugiyanti',
#  'eksek': 'eksekutif',
#  'manaj': 'manajemen',
#  'piy': 'piyung',
#  'mikh': 'mikhael',
#  'riaduss': 'riadussolihin',
#  'pelin': 'pelindung',
#  'scient': 'scientific',
#  'ojol': 'ojolali',
#  'randus': 'randusongo',
#  'comb': 'comboran',
#  'mendr': 'mendrisio',
#  'mainte': 'maintenance',
#  'kapli': 'kaplingan',
#  'dyn': 'dynamo',
#  'al-ir': 'al-irsyad',
#  'puranaw': 'puranawarman',
#  'kepoli': 'kepolisian',
#  'ticke': 'ticketing',
#  'mabr': 'mabruroh',
#  'prayu': 'prayungan',
#  'groj': 'grojogan',
#  'serun': 'serundeng',
#  'kenda': 'kendaraan',
#  'kotamo': 'kotamobagu',
#  'nahd': 'nahdatul',
#  'reso': 'resorts',
#  'bangba': 'bangbarung',
#  'mosh': 'moshaict',
#  'mitsub': 'mitsubishi',
#  'narko': 'narkotika',
#  'dikp': 'dikpora',
#  'adiper': 'adiperkasa',
#  'ense': 'enseval',
#  'sounds': 'soundsystem',
#  'protec': 'protection',
#  'riso': 'risoles',
#  'matema': 'matematika',
#  'jewe': 'jewelry',
#  'masbelakang': 'belakang',
#  'karangs': 'karangsambung',
#  'joer': 'joeragan',
#  'kopr': 'koprasi',
#  "syafi'": "syafi'iyah",
#  'indovi': 'indovision',
#  'humb': 'humbang',
#  'hasund': 'hasundutan',
#  'thol': 'tholibin',
#  'sawahl': 'sawahlunto',
#  'vapes': 'vapestore',
#  'katre': 'katresnan',
#  'mencir': 'menciripin',
#  'godong-pu': 'godong-purwodadi',
#  'yom': 'yomart',
#  'poske': 'poskesdes',
#  'parc': 'parcell',
#  'sutawin': 'sutawinangun',
#  'ghuf': 'ghufron',
#  'mote': 'motekar',
#  'wonosobo-p': 'wonosobo-purworejo',
#  'pati-g': 'pati-gabus',
#  'rwkolong': 'kolong',
#  'ijt': 'ijtima',
#  'ditla': 'ditlantas',
#  'martasa': 'martasasmita',
#  'gemil': 'gemilang',
#  'capt': 'captain',
#  'nood': 'noodles',
#  'bismi': 'bismillah',
#  'samratu': 'samratulangi',
#  'neoc': 'neocell',
#  'munaww': 'munawwarah',
#  'brea': 'breaker',
#  'budim': 'budimulia',
#  'awn': 'awning',
#  'carre': 'carrefour',
#  'kusumaw': 'kusumawardani',
#  'fransi': 'fransiskus',
#  'kimb': 'kimberly',
#  'sna': 'snacks',
#  'aritma': 'aritmatika',
#  'longke': 'longkewang',
#  'geop': 'geopark',
#  'sudarm': 'sudarmanto',
#  'takmil': 'takmiliyah',
#  'ekle': 'eklesia',
#  'divi': 'division',
#  'floba': 'flobamora',
#  'drill': 'drillindo',
#  'olym': 'olympic',
#  'nuzu': 'nuzulul',
#  'veteri': 'veterinary',
#  'opt': 'optima',
#  'jerort': 'jero',
#  'giy': 'giyono',
#  'ekow': 'ekowati',
#  'kelont': 'kelontongan',
#  'cop': 'copier',
#  'lamina': 'laminating',
#  'tabl': 'tabloid',
#  'cibole': 'cibolerang',
#  'sastrad': 'sastradikarta',
#  'idol': 'idolmart',
#  'yogh': 'yoghurt',
#  'sett': 'setting',
#  "mu'aw": "mu'awanah",
#  'turk': 'turkish',
#  'mallen': 'mallengkeri',
#  'suka-': 'suka-suka',
#  'panw': 'panwaslu',
#  'amaz': 'amazing',
#  'expl': 'explore',
#  'purnom': 'purnomosidi',
#  'vouc': 'voucher',
#  'tunan': 'tunanetra',
#  'daih': 'daihatsu',
#  'kame': 'kamelia',
#  'author': 'authorized',
#  'pemoto': 'pemotongan',
#  'meub': 'meubeul',
#  'surodi': 'surodinawan',
#  'sakar': 'sakaruhun',
#  'kesyahba': 'kesyahbandaran',
#  'polte': 'poltekkes',
#  'satla': 'satlantas',
#  'shib': 'shibyan',
#  'kedir': 'kediri-ke',
#  'souve': 'souvenirs',
#  'wonde': 'wonderful',
#  'sunc': 'suncity',
#  'sikum': 'sikumbang',
#  'peke': 'pekerja',
#  'psiko': 'psikologi',
#  'dare': 'dareh-ju',
#  'seq': 'sequis',
#  'kreas': 'kreasindo',
#  'hiz': 'hizbul',
#  'gunungs': 'gunungsitoli',
#  'croco': 'crocodile',
#  'cath': 'catholic',
#  'pujunga': 'pujungan-pupu',
#  'olymp': 'olympindo',
#  'diap': 'diapers',
#  'assal': 'assalamah',
#  'pekub': 'pekuburan',
#  'kath': 'katholik',
#  'mujahi': 'mujahiddin',
#  'empe': 'emperan',
#  'ihs': 'ihsani',
#  'wend': "wendy's",
#  'kopo-so': 'kopo-soreang',
#  'somet': 'something',
#  'djalal': 'djalaludin',
#  'extr': 'extreme',
#  'pangga': 'panggabean',
#  'saep': 'saepudin',
#  'fakh': 'fakhrul',
#  'milks': 'milkshake',
#  'bugenv': 'bugenville',
#  'lazu': 'lazuardi',
#  'zamb': 'zambrud',
#  'mewa': 'mewarnai',
#  'boedja': 'boedjangan',
#  'pohu': 'pohuwato',
#  'slee': 'sleeping',
#  'kulonp': 'kulonprogo',
#  'treat': 'treatment',
#  'kerung-': 'kerung-kerung',
#  'catte': 'cattering',
#  'kebond': 'kebondalem',
#  'pemul': 'pemulihan',
#  'madd': 'maddies',
#  'saef': 'saefudin',
#  'inspi': 'inspirasi',
#  'petite': 'petitenget',
#  'bersub': 'bersubsidi',
#  'whe': 'wheels',
#  'khri': 'khrisna',
#  'omp': 'omponk',
#  'roch': 'rochman',
#  'kalb': 'kalbar',
#  'chart': 'chartered',
#  'isab': 'isabella',
#  'penger': 'pengerajin',
#  'oper': 'operator',
#  'megas': 'megastore',
#  'homed': 'homedecor',
#  'bawaka': 'bawakareng',
#  'raks': 'raksasa',
#  'enginee': 'engineering',
#  'imit': 'imitasi',
#  'samari': 'samarinda-',
#  'rica-': 'rica-rica',
#  'perbela': 'perbelanjaan',
#  'chel': 'chelsea',
#  'pemes': 'pemesanan',
#  'komput': 'komputindo',
#  'tanjab-s': 'tanjab-simpang',
#  'mulj': 'muljono',
#  'subs': 'subsidi',
#  'habb': "habbat's",
#  'baskin-r': 'baskin-robbins',
#  'shut': 'shuttle',
#  'pict': 'pictures',
#  'martu': 'martubung',
#  'persaud': 'persaudaraan',
#  'ihsa': 'ihsanul',
#  'ime': 'imelda',
#  'popola': 'popolamama',
#  'wonoso': 'wonosobo-p',
#  'kerton': 'kertonegoro',
#  'brilin': 'brilinklink',
#  'rayh': 'rayhana',
#  'manufac': 'manufacturing',
#  'consu': 'consultan',
#  'mum': 'mumtaz',
#  'kebug': 'kebugaran',
#  'perwa': 'perwanida',
#  'ketram': 'ketrampilan',
#  'rodi': 'rodiyah',
#  'kalibu': 'kalibukbuk',
#  'akunt': 'akuntansi',
#  'soegiyop': 'soegiyopranoto',
#  'gelon': 'gelondong',
#  'peliha': 'peliharaan',
#  'ramad': 'ramadhani',
#  'asseso': 'assesories',
#  'pemer': 'pemeriksa',
#  'oikou': 'oikoumene',
#  'greenv': 'greenville',
#  'penget': 'pengetikan',
#  'nutr': 'nutricia',
#  'fab': 'fabian',
#  'sulisti': 'sulistiawati',
#  'syib': 'syibyan',
#  'blackb': 'blackberry',
#  'upno': 'upnormal',
#  'honggok': 'honggokusuman',
#  'pengaw': 'pengawasan',
#  'pharmace': 'pharmaceutical',
#  'tur': 'turkey',
#  'brothe': 'brotherhood',
#  'tiff': 'tiffani',
#  'poul': 'poultry',
#  'oore': 'ooredoo',
#  'salat': 'salatiga-',
#  'audito': 'auditorium',
#  'mujtah': 'mujtahidin',
#  'mardhot': 'mardhotillah',
#  'sidim': 'sidimpuan',
#  'baih': 'baihaqi',
#  'cuis': 'cuisine',
#  'kebona': 'kebonagung',
#  'sumiy': 'sumiyatun',
#  'secur': 'securindo',
#  'akseso': 'aksesories',
#  'fotog': 'fotografi',
#  'minh': 'minhajut',
#  'kendald': 'kendaldoyong',
#  'enterp': 'enterprise',
#  'balc': 'balcony',
#  'yasi': 'yasinan',
#  'supriy': 'supriyanto',
#  'kanggr': 'kanggraksan',
#  '11lapangan': 'lapangan',
#  'cakran': 'cakranegara',
#  'pancure': 'pancurendang',
#  'wijayak': 'wijayakusuma',
#  'uss': 'ussisa',
#  'alatt': 'alattaqwa',
#  'inj': 'injili',
#  'orif': 'oriflame',
#  'hidrop': 'hidroponik',
#  'smartp': 'smartphone',
#  'laundr': 'laundryklin',
#  'jarima': 'jarimatika',
#  'magf': 'magfiroh',
#  'coke': 'cokelat',
#  'aces': 'acesoris',
#  'virt': 'virtual',
#  'iceb': 'iceblend',
#  'fict': 'fictory',
#  'gior': 'giordano',
#  'exch': 'exchange',
#  'masbagi': 'masbagik-prin',
#  'ptkn:terminal': 'terminal',
#  'hant': 'hantaran',
#  'broi': 'broiler',
#  'eyel': 'eyelash',
#  'multia': 'multiartha',
#  'pembib': 'pembibitan',
#  'sirnag': 'sirnagalih',
#  'autom': 'automatic',
#  'mlatih': 'mlatiharjo',
#  'suks': 'sukses',
#  'khad': 'khadijah',
#  'kalite': 'kalitengah',
#  'sawerig': 'sawerigading',
#  'pembah': 'pembaharuan',
#  'spiri': 'spiritual',
#  'bireuen': 'bireuen-batas',
#  'ors': 'orshid',
#  'perbau': 'perbaungan',
#  'penuk': 'penukaran',
#  'jamkr': 'jamkrindo',
#  'branja': 'branjangan',
#  'al-muqo': 'al-muqorrobin',
#  'fron': 'frontier',
#  'k-l': 'k-link',
#  'omet': 'ometraco',
#  'dwid': 'dwidaya',
#  'refr': 'refresh',
#  'raz': 'razali',
#  'foot': 'footwear',
#  'wates-n': 'wates-ngoro-',
#  'tamans': 'tamansiswa',
#  ':ruko': 'ruko',
#  'iny': 'inyong',
#  'nec': 'necizz',
#  'ite': 'iteung',
#  'safin': 'safinatun',
#  'commonw': 'commonwealth',
#  'retr': 'retreat',
#  'achi': 'achilles',
#  'pengang': 'pengangkutan',
#  'sonj': 'sonjaya',
#  'dunk': "dunkin'",
#  'oxf': 'oxford',
#  'punok': 'punokawan',
#  'naingg': 'nainggolan',
#  'marw': 'marwiyah',
#  'twe': 'twenty',
#  'ambass': 'ambassador',
#  'sni': 'sniper',
#  'emin': 'eminence',
#  'komer': 'komersial',
#  'adij': 'adijaya',
#  'kurn': 'kurniati',
#  'roudh': 'roudhotul',
#  'barc': 'barcode',
#  'atohar': 'atohariyah',
#  'minhajutt': 'minhajutthollab',
#  'senn': 'sennaart',
#  'caval': 'cavallino',
#  'grey': 'grey101',
#  'spesia': 'spesialist',
#  'indocar': 'indocarpenter',
#  'makh': 'makhasi',
#  'pulori': 'puloriburit',
#  'lup': 'lupita',
#  'cosmat': 'cosmaterial',
#  'miea': 'mieayam',
#  'pasirj': 'pasirjambu',
#  'rank': 'rankoto',
#  'kerli': 'kerlipan',
#  'suryaa': 'suryaatmaja',
#  'alams': 'alamsyah',
#  'viek': 'vieklin',
#  'nyitz': 'nyitzfood',
#  'sulaima': 'sulaimaniyah',
#  'catterp': 'catterpilars',
#  'rasmiy': 'rasmiyatun',
#  'baratterminal': 'terminal',
#  'weed': 'weeding',
#  'adyaw': 'adyawinsa',
#  'nikko': 'nikkotama',
#  'rorome': 'roromendut',
#  'gd2': 'gd2205',
#  'ghon': 'ghoniyah',
#  'tourst': 'tourstravel',
#  ...}

# %% [markdown]
# ## Checking

# %%
df = pd.read_csv('data/processed_train.csv')
df.head()
# Out:
#                                          raw_address  \
# 0  jl kapuk timur delta sili iii lippo cika 11 a ...
# 1               setu siung 119 rt 5 1 13880 cipayung
# 2                              toko dita , kertosono
# 3                                      jl. orde baru
# 4                  raya samb gede , 299 toko bb kids
#
#                                   POI/street
# 0  /jl kapuk timur delta sili iii lippo cika
# 1                                     /siung
# 2                                 toko dita/
# 3                             /jl. orde baru
# 4                toko bb kids/raya samb gede

# %%
def repair(text) :
    words = text.split(" ")
    for i in range(len(words)) :
        if words[i] in small_dict :
            words[i] = small_dict[words[i]]
    return " ".join(words)

# %%
df["raw_address"] = df["raw_address"].apply(repair)

# %%
cdf = pd.read_csv('data/cleaned_train.csv')
cdf.head()
# Out:
#                                          raw_address  \
# 0  jl kapuk timur delta sili iii lippo cika 11 a ...
# 1               setu siung 119 rt 5 1 13880 cipayung
# 2                              toko dita , kertosono
# 3                                      jl. orde baru
# 4                  raya samb gede , 299 toko bb kids
#
#                                   POI/street
# 0  /jl kapuk timur delta sili iii lippo cika
# 1                                     /siung
# 2                                 toko dita/
# 3                             /jl. orde baru
# 4                toko bb kids/raya samb gede

# %%
len(df)
# Out:
# 265888

# %%
len(cdf)
# Out:
# 265888

# %%
check = df["raw_address"] == cdf["raw_address"]
sum(check)/len(check)
# Out:
# 0.7944510470574077

# %%
tdf = pd.read_csv('data/processed_test.csv')
tdf["raw_address"] = tdf["raw_address"].apply(repair)

# %%
tdf.to_csv("data/cleaned_test.csv", index=False)
