# %% [markdown]
# # Data Cleaning

# %%
import re
from collections import Counter 

import pandas as pd
import numpy as np


import warnings
warnings.filterwarnings('ignore')

# %%
data_dir = "data/"
df = pd.read_csv(data_dir + "train.csv")
dft = pd.read_csv(data_dir + "test.csv")

# %%
#### for testing purpose
# df = df[:200]

# %%
df
# Out:
#             id                                        raw_address  \
# 0            0  jl kapuk timur delta sili iii lippo cika 11 a ...
# 1            1                                 aye, jati sampurna
# 2            2               setu siung 119 rt 5 1 13880 cipayung
# 3            3                               toko dita, kertosono
# 4            4                                      jl. orde baru
# ...        ...                                                ...
# 299995  299995               jend ahmad yani 331 kertasari ciamis
# 299996  299996                 raya cila kko, cilandak timur kel.
# 299997  299997                     tanjung gusta jl. yaya 2 no 17
# 299998  299998  jalan cipadu jaya taman asri gang bijaksana 3 ...
# 299999  299999          jaya maspion permata blok beryl b2  no.58
#
#                                        POI/street
# 0       /jl kapuk timur delta sili iii lippo cika
# 1                                               /
# 2                                          /siung
# 3                                      toko dita/
# 4                                  /jl. orde baru
# ...                                           ...
# 299995                           /jend ahmad yani
# 299996                             /raya cila kko
# 299997                                          /
# 299998                                taman asri/
# 299999                      jaya maspion permata/
#
# [300000 rows x 3 columns]

# %% [markdown]
# ### Remove Whitespace

# %%
# remove multiple whitespace
# cover tabs and newlines also
def remove_multiple_whitespace(text) :
    return re.sub(' +', ' ', text.replace('\n', ' ').replace('\t', ' ')).strip()

# %%
remove_multiple_whitespace(" asfua asfasbiuf \n \t  asfsa adfgas \t d ")
# Out:
# 'asfua asfasbiuf asfsa adfgas d'

# %%
df["raw_address"] = df["raw_address"].apply(remove_multiple_whitespace)
df["POI/street"] = df["POI/street"].apply(remove_multiple_whitespace)

# %% [markdown]
# ### Only use data with having at least POI or street

# %%
df = df[df["POI/street"] != "/"]
df
# Out:
#             id                                        raw_address  \
# 0            0  jl kapuk timur delta sili iii lippo cika 11 a ...
# 2            2               setu siung 119 rt 5 1 13880 cipayung
# 3            3                               toko dita, kertosono
# 4            4                                      jl. orde baru
# 5            5                   raya samb gede, 299 toko bb kids
# ...        ...                                                ...
# 299994  299994    karawaci baru kakap raya 156 rt 1 rw 3 karawaci
# 299995  299995               jend ahmad yani 331 kertasari ciamis
# 299996  299996                 raya cila kko, cilandak timur kel.
# 299998  299998  jalan cipadu jaya taman asri gang bijaksana 3 ...
# 299999  299999           jaya maspion permata blok beryl b2 no.58
#
#                                        POI/street
# 0       /jl kapuk timur delta sili iii lippo cika
# 2                                          /siung
# 3                                      toko dita/
# 4                                  /jl. orde baru
# 5                     toko bb kids/raya samb gede
# ...                                           ...
# 299994                                /kakap raya
# 299995                           /jend ahmad yani
# 299996                             /raya cila kko
# 299998                                taman asri/
# 299999                      jaya maspion permata/
#
# [268007 rows x 3 columns]

# %%
df[['POI', 'Street']] = df['POI/street'].str.split('/', 1, expand=True)

# %%
# Empty POI
len(df[df['POI'] == ''])
# Out:
# 146516

# %%
# Empty Street
len(df[df['Street'] == ''])
# Out:
# 38150

# %% [markdown]
# ## Number of Dot in POI and Street

# %%
x = df["POI"].apply(lambda x : "." in x)
sum(x)
# Out:
# 6464

# %%
x = df["Street"].apply(lambda x : "." in x)
sum(x)
# Out:
# 29080

# %%
df["SplitPOI"] = df["POI"].str.split(" ")
df["SplitStreet"] = df["Street"].str.split(" ")
df["SplitRaw"] = df["raw_address"].str.split(" ")

# %%
dot_tokens = []

# %%
for tokens in df["SplitPOI"].tolist() + df["SplitStreet"].tolist() :
    for token in tokens :
        if "." in token :
            dot_tokens.append(token)

# %%
count = Counter(dot_tokens)

# %%
count.most_common()[:20]
# Out:
# [('gg.', 10709),
#  ('jl.', 9731),
#  ('h.', 2013),
#  ('dr.', 959),
#  ('pt.', 723),
#  ('kh.', 650),
#  ('a.', 602),
#  ('r.', 588),
#  ('s.', 575),
#  ('kel.', 547),
#  ('jln.', 507),
#  ('m.', 492),
#  ('ud.', 456),
#  ('ir.', 448),
#  ('p.', 384),
#  ('jend.', 291),
#  ('cv.', 256),
#  ('prof.', 221),
#  ('k.', 221),
#  ('kp.', 205)]

# %%
unique_dot_tokens = set(dot_tokens)

# %%
## remove dot if the token doesn't 
def remove_dot(text) :
    words = text.split(" ")
    for i in range(len(words)) :
        if "." in words[i] and words[i] not in unique_dot_tokens :
            words[i] = words[i].replace(".", " ").strip()
    return " ".join(words)

# %%
words = ['batu', 'flower', 'garden.', 'ds.', 'dresel.', 'oro-oro', 'ombo.', 'batu.', 'kota', 'batu']
text = " ".join(words)
remove_dot(text)
# Out:
# 'batu flower garden ds. dresel oro-oro ombo batu kota batu'

# %%
df["raw_address"] = df["raw_address"].apply(remove_dot)

df["SplitRaw"] = df["raw_address"].str.split(" ")
df.head()
# Out:
#    id                                        raw_address  \
# 0   0  jl kapuk timur delta sili iii lippo cika 11 a ...
# 2   2               setu siung 119 rt 5 1 13880 cipayung
# 3   3                               toko dita, kertosono
# 4   4                                      jl. orde baru
# 5   5                   raya samb gede, 299 toko bb kids
#
#                                   POI/street           POI  \
# 0  /jl kapuk timur delta sili iii lippo cika
# 2                                     /siung
# 3                                 toko dita/     toko dita
# 4                             /jl. orde baru
# 5                toko bb kids/raya samb gede  toko bb kids
#
#                                      Street          SplitPOI  \
# 0  jl kapuk timur delta sili iii lippo cika                []
# 2                                     siung                []
# 3                                                [toko, dita]
# 4                             jl. orde baru                []
# 5                            raya samb gede  [toko, bb, kids]
#
#                                          SplitStreet  \
# 0  [jl, kapuk, timur, delta, sili, iii, lippo, cika]
# 2                                            [siung]
# 3                                                 []
# 4                                  [jl., orde, baru]
# 5                                 [raya, samb, gede]
#
#                                             SplitRaw
# 0  [jl, kapuk, timur, delta, sili, iii, lippo, ci...
# 2      [setu, siung, 119, rt, 5, 1, 13880, cipayung]
# 3                           [toko, dita,, kertosono]
# 4                                  [jl., orde, baru]
# 5           [raya, samb, gede,, 299, toko, bb, kids]

# %% [markdown]
# ## Number of Comma in POI and Street

# %%
x = df["POI"].apply(lambda x : "," in x)
sum(x)
# Out:
# 918

# %%
x = df["Street"].apply(lambda x : "," in x)
sum(x)
# Out:
# 1176

# %% [markdown]
# The number is not significant compared to 300k, thus we can drop it to make the training data cleaner

# %%
comma_tokens = []

# %%
for tokens in df["SplitPOI"].tolist() + df["SplitStreet"].tolist() :
    for token in tokens :
        if "," in token :
            comma_tokens.append(token)

# %%
count = Counter(comma_tokens)

# %%
count.most_common()[:15]
# Out:
# [('ii,', 107),
#  ('raya,', 87),
#  ('i,', 66),
#  ('iii,', 56),
#  ('2,', 46),
#  ('baru,', 40),
#  ('iv,', 36),
#  ('1,', 35),
#  ('v,', 35),
#  ('jaya,', 30),
#  ('4,', 27),
#  ('sh.,', 26),
#  ('jl,', 26),
#  ('3,', 23),
#  ('lor,', 22)]

# %% [markdown]
# drop train data if the POI or street contain comma ","

# %%
def drop_column_contain_comma(df, column_name) :
    return df[df[column_name].apply(lambda x : "," not in x)]
    
df = drop_column_contain_comma(df, "POI")
df = drop_column_contain_comma(df, "Street")
df
# Out:
#             id                                        raw_address  \
# 0            0  jl kapuk timur delta sili iii lippo cika 11 a ...
# 2            2               setu siung 119 rt 5 1 13880 cipayung
# 3            3                               toko dita, kertosono
# 4            4                                      jl. orde baru
# 5            5                   raya samb gede, 299 toko bb kids
# ...        ...                                                ...
# 299994  299994    karawaci baru kakap raya 156 rt 1 rw 3 karawaci
# 299995  299995               jend ahmad yani 331 kertasari ciamis
# 299996  299996                 raya cila kko, cilandak timur kel.
# 299998  299998  jalan cipadu jaya taman asri gang bijaksana 3 ...
# 299999  299999           jaya maspion permata blok beryl b2 no 58
#
#                                        POI/street                   POI  \
# 0       /jl kapuk timur delta sili iii lippo cika
# 2                                          /siung
# 3                                      toko dita/             toko dita
# 4                                  /jl. orde baru
# 5                     toko bb kids/raya samb gede          toko bb kids
# ...                                           ...                   ...
# 299994                                /kakap raya
# 299995                           /jend ahmad yani
# 299996                             /raya cila kko
# 299998                                taman asri/            taman asri
# 299999                      jaya maspion permata/  jaya maspion permata
#
#                                           Street                  SplitPOI  \
# 0       jl kapuk timur delta sili iii lippo cika                        []
# 2                                          siung                        []
# 3                                                             [toko, dita]
# 4                                  jl. orde baru                        []
# 5                                 raya samb gede          [toko, bb, kids]
# ...                                          ...                       ...
# 299994                                kakap raya                        []
# 299995                           jend ahmad yani                        []
# 299996                             raya cila kko                        []
# 299998                                                       [taman, asri]
# 299999                                            [jaya, maspion, permata]
#
#                                               SplitStreet  \
# 0       [jl, kapuk, timur, delta, sili, iii, lippo, cika]
# 2                                                 [siung]
# 3                                                      []
# 4                                       [jl., orde, baru]
# 5                                      [raya, samb, gede]
# ...                                                   ...
# 299994                                      [kakap, raya]
# 299995                                [jend, ahmad, yani]
# 299996                                  [raya, cila, kko]
# 299998                                                 []
# 299999                                                 []
#
#                                                  SplitRaw
# 0       [jl, kapuk, timur, delta, sili, iii, lippo, ci...
# 2           [setu, siung, 119, rt, 5, 1, 13880, cipayung]
# 3                                [toko, dita,, kertosono]
# 4                                       [jl., orde, baru]
# 5                [raya, samb, gede,, 299, toko, bb, kids]
# ...                                                   ...
# 299994  [karawaci, baru, kakap, raya, 156, rt, 1, rw, ...
# 299995        [jend, ahmad, yani, 331, kertasari, ciamis]
# 299996          [raya, cila, kko,, cilandak, timur, kel.]
# 299998  [jalan, cipadu, jaya, taman, asri, gang, bijak...
# 299999  [jaya, maspion, permata, blok, beryl, b2, no, 58]
#
# [265921 rows x 8 columns]

# %%
# since the number is small, and the occurance is odd
# we can restructure space in raw_address
def restructure_comma(text) :
    return remove_multiple_whitespace(text.replace(",", " , ")).strip()

# %%
df["raw_address"] = df["raw_address"].apply(restructure_comma)
df["POI/street"] = df["POI/street"].apply(restructure_comma)

df[["POI", "Street"]] = df["POI/street"].str.split("/", 1, expand=True)

df["SplitRaw"] = df["raw_address"].str.split(" ")
df["SplitPOI"] = df["POI"].str.split(" ")
df["SplitStreet"] = df["Street"].str.split(" ")

df.head()
# Out:
#    id                                        raw_address  \
# 0   0  jl kapuk timur delta sili iii lippo cika 11 a ...
# 2   2               setu siung 119 rt 5 1 13880 cipayung
# 3   3                              toko dita , kertosono
# 4   4                                      jl. orde baru
# 5   5                  raya samb gede , 299 toko bb kids
#
#                                   POI/street           POI  \
# 0  /jl kapuk timur delta sili iii lippo cika
# 2                                     /siung
# 3                                 toko dita/     toko dita
# 4                             /jl. orde baru
# 5                toko bb kids/raya samb gede  toko bb kids
#
#                                      Street          SplitPOI  \
# 0  jl kapuk timur delta sili iii lippo cika                []
# 2                                     siung                []
# 3                                                [toko, dita]
# 4                             jl. orde baru                []
# 5                            raya samb gede  [toko, bb, kids]
#
#                                          SplitStreet  \
# 0  [jl, kapuk, timur, delta, sili, iii, lippo, cika]
# 2                                            [siung]
# 3                                                 []
# 4                                  [jl., orde, baru]
# 5                                 [raya, samb, gede]
#
#                                             SplitRaw
# 0  [jl, kapuk, timur, delta, sili, iii, lippo, ci...
# 2      [setu, siung, 119, rt, 5, 1, 13880, cipayung]
# 3                         [toko, dita, ,, kertosono]
# 4                                  [jl., orde, baru]
# 5         [raya, samb, gede, ,, 299, toko, bb, kids]

# %% [markdown]
# ## Number of ( in POI and Street

# %%
x = df["POI"].apply(lambda x : "(" in x)
sum(x)
# Out:
# 519

# %%
df[df["POI"].apply(lambda x : "(" in x)]
# Out:
#             id                                        raw_address  \
# 898        898  duy , kary novo hotel batam (kop novo) , lubuk...
# 967        967  eka sari lor transport. pt - agen andongsari -...
# 4382      4382  bank rakyat indonesia (persero) tbk. pt , haur...
# 4547      4547  askes. pt (persero) - sema , sul agung gajah m...
# 7850      7850  dr raji no 107 batik artha (mbak muji) , sri w...
# ...        ...                                                ...
# 296842  296842  kebun sayur organik (kso) dusun wuni , pasuruh...
# 297334  297334    pao telo (bak telo) , borob mojolangu lowokwaru
# 297514  297514              raudhatul athfa (ra) nasiatul mubta 1
# 298010  298010   lya & nurul (lyn) , m h tham boule , tanah abang
# 298818  298818  sekolah dasar negeri (sdn) 190 , r kemu , ario...
#
#                                                POI/street  \
# 898        karyawan novotel hotel batam (kopkar novo)/duy
# 967     eka sari lorena transport. pt - agen andongsar...
# 4382             bank rakyat indonesia (persero) tbk. pt/
# 4547             askes. pt (persero) - semarang/sul agung
# 7850                      batik artha (mbak muji)/dr raji
# ...                                                   ...
# 296842                         kebun sayur organik (kso)/
# 297334                       pao telo (bakpao telo)/borob
# 297514         raudhatul athfa (ra) nasiatul mubtadiin 1/
# 298010                   lya & nurul (lyn)/m h tham boule
# 298818              sekolah dasar negeri (sdn) 190/r kemu
#
#                                                       POI          Street  \
# 898            karyawan novotel hotel batam (kopkar novo)             duy
# 967     eka sari lorena transport. pt - agen andongsar...         dharmaw
# 4382              bank rakyat indonesia (persero) tbk. pt
# 4547                       askes. pt (persero) - semarang       sul agung
# 7850                              batik artha (mbak muji)         dr raji
# ...                                                   ...             ...
# 296842                          kebun sayur organik (kso)
# 297334                             pao telo (bakpao telo)           borob
# 297514          raudhatul athfa (ra) nasiatul mubtadiin 1
# 298010                                  lya & nurul (lyn)  m h tham boule
# 298818                     sekolah dasar negeri (sdn) 190          r kemu
#
#                                                  SplitPOI  \
# 898     [karyawan, novotel, hotel, batam, (kopkar, novo)]
# 967     [eka, sari, lorena, transport., pt, -, agen, a...
# 4382       [bank, rakyat, indonesia, (persero), tbk., pt]
# 4547                 [askes., pt, (persero), -, semarang]
# 7850                         [batik, artha, (mbak, muji)]
# ...                                                   ...
# 296842                     [kebun, sayur, organik, (kso)]
# 297334                        [pao, telo, (bakpao, telo)]
# 297514   [raudhatul, athfa, (ra), nasiatul, mubtadiin, 1]
# 298010                             [lya, &, nurul, (lyn)]
# 298818               [sekolah, dasar, negeri, (sdn), 190]
#
#                 SplitStreet                                           SplitRaw
# 898                   [duy]  [duy, ,, kary, novo, hotel, batam, (kop, novo)...
# 967               [dharmaw]  [eka, sari, lor, transport., pt, -, agen, ando...
# 4382                     []  [bank, rakyat, indonesia, (persero), tbk., pt,...
# 4547           [sul, agung]  [askes., pt, (persero), -, sema, ,, sul, agung...
# 7850             [dr, raji]  [dr, raji, no, 107, batik, artha, (mbak, muji)...
# ...                     ...                                                ...
# 296842                   []  [kebun, sayur, organik, (kso), dusun, wuni, ,,...
# 297334              [borob]  [pao, telo, (bak, telo), ,, borob, mojolangu, ...
# 297514                   []       [raudhatul, athfa, (ra), nasiatul, mubta, 1]
# 298010  [m, h, tham, boule]  [lya, &, nurul, (lyn), ,, m, h, tham, boule, ,...
# 298818            [r, kemu]  [sekolah, dasar, negeri, (sdn), 190, ,, r, kem...
#
# [519 rows x 8 columns]

# %%
x = df["Street"].apply(lambda x : "(" in x)
sum(x)
# Out:
# 9

# %%
df[df["Street"].apply(lambda x : "(" in x)]
# Out:
#             id                                        raw_address  \
# 6230      6230     indo alam (da pemb , tegalsawah karawang timur
# 34918    34918           (seb jemb sun pelus kedungmalang sumbang
# 41168    41168                               a.r.h (kom beji beji
# 53618    53618  hidup baru 3 (haji ahm gandaria utara kebayora...
# 176537  176537  ( setia jaya 7 jelambar baru rt 1 6 grogol pet...
# 213027  213027  rusunawa pesakih (rptra) , jl. daan mogot(desa...
# 225190  225190               (de sd haur gg. ii lebakgede coblong
# 230539  230539  (seb spbu motor kelur sumbe sumber rejo balikp...
# 273268  273268                             (j-2) 16 dadap kosambi
#
#                                            POI/street               POI  \
# 6230                              /indo alam (da pemb
# 34918                            /(seb jemb sun pelus
# 41168                                     /a.r.h (kom
# 53618                         /hidup baru 3 (haji ahm
# 176537                                  /( setia jaya
# 213027  rusunawa pesakih/jl. daan mogot(desa semanan)  rusunawa pesakih
# 225190                            /(de sd haur gg. ii
# 230539                   /(seb spbu motor kelur sumbe
# 273268                                         /(j-2)
#
#                               Street             SplitPOI  \
# 6230              indo alam (da pemb                   []
# 34918            (seb jemb sun pelus                   []
# 41168                     a.r.h (kom                   []
# 53618         hidup baru 3 (haji ahm                   []
# 176537                  ( setia jaya                   []
# 213027  jl. daan mogot(desa semanan)  [rusunawa, pesakih]
# 225190            (de sd haur gg. ii                   []
# 230539   (seb spbu motor kelur sumbe                   []
# 273268                         (j-2)                   []
#
#                               SplitStreet  \
# 6230              [indo, alam, (da, pemb]
# 34918            [(seb, jemb, sun, pelus]
# 41168                       [a.r.h, (kom]
# 53618        [hidup, baru, 3, (haji, ahm]
# 176537                   [(, setia, jaya]
# 213027  [jl., daan, mogot(desa, semanan)]
# 225190           [(de, sd, haur, gg., ii]
# 230539  [(seb, spbu, motor, kelur, sumbe]
# 273268                            [(j-2)]
#
#                                                  SplitRaw
# 6230    [indo, alam, (da, pemb, ,, tegalsawah, karawan...
# 34918     [(seb, jemb, sun, pelus, kedungmalang, sumbang]
# 41168                           [a.r.h, (kom, beji, beji]
# 53618   [hidup, baru, 3, (haji, ahm, gandaria, utara, ...
# 176537  [(, setia, jaya, 7, jelambar, baru, rt, 1, 6, ...
# 213027  [rusunawa, pesakih, (rptra), ,, jl., daan, mog...
# 225190       [(de, sd, haur, gg., ii, lebakgede, coblong]
# 230539  [(seb, spbu, motor, kelur, sumbe, sumber, rejo...
# 273268                        [(j-2), 16, dadap, kosambi]

# %% [markdown]
# drop if the POI/street contain left bracket ( without right bracket ) or vice versa

# %%
df = df[df["POI/street"].apply(lambda x : not( ( "(" in x and ")" not in x ) or ( ")" in x and "(" not in x ) ) )]

# %%
df[df["POI"].apply(lambda x : "(" in x)]
# Out:
#             id                                        raw_address  \
# 898        898  duy , kary novo hotel batam (kop novo) , lubuk...
# 967        967  eka sari lor transport. pt - agen andongsari -...
# 4382      4382  bank rakyat indonesia (persero) tbk. pt , haur...
# 4547      4547  askes. pt (persero) - sema , sul agung gajah m...
# 7850      7850  dr raji no 107 batik artha (mbak muji) , sri w...
# ...        ...                                                ...
# 296842  296842  kebun sayur organik (kso) dusun wuni , pasuruh...
# 297334  297334    pao telo (bak telo) , borob mojolangu lowokwaru
# 297514  297514              raudhatul athfa (ra) nasiatul mubta 1
# 298010  298010   lya & nurul (lyn) , m h tham boule , tanah abang
# 298818  298818  sekolah dasar negeri (sdn) 190 , r kemu , ario...
#
#                                                POI/street  \
# 898        karyawan novotel hotel batam (kopkar novo)/duy
# 967     eka sari lorena transport. pt - agen andongsar...
# 4382             bank rakyat indonesia (persero) tbk. pt/
# 4547             askes. pt (persero) - semarang/sul agung
# 7850                      batik artha (mbak muji)/dr raji
# ...                                                   ...
# 296842                         kebun sayur organik (kso)/
# 297334                       pao telo (bakpao telo)/borob
# 297514         raudhatul athfa (ra) nasiatul mubtadiin 1/
# 298010                   lya & nurul (lyn)/m h tham boule
# 298818              sekolah dasar negeri (sdn) 190/r kemu
#
#                                                       POI          Street  \
# 898            karyawan novotel hotel batam (kopkar novo)             duy
# 967     eka sari lorena transport. pt - agen andongsar...         dharmaw
# 4382              bank rakyat indonesia (persero) tbk. pt
# 4547                       askes. pt (persero) - semarang       sul agung
# 7850                              batik artha (mbak muji)         dr raji
# ...                                                   ...             ...
# 296842                          kebun sayur organik (kso)
# 297334                             pao telo (bakpao telo)           borob
# 297514          raudhatul athfa (ra) nasiatul mubtadiin 1
# 298010                                  lya & nurul (lyn)  m h tham boule
# 298818                     sekolah dasar negeri (sdn) 190          r kemu
#
#                                                  SplitPOI  \
# 898     [karyawan, novotel, hotel, batam, (kopkar, novo)]
# 967     [eka, sari, lorena, transport., pt, -, agen, a...
# 4382       [bank, rakyat, indonesia, (persero), tbk., pt]
# 4547                 [askes., pt, (persero), -, semarang]
# 7850                         [batik, artha, (mbak, muji)]
# ...                                                   ...
# 296842                     [kebun, sayur, organik, (kso)]
# 297334                        [pao, telo, (bakpao, telo)]
# 297514   [raudhatul, athfa, (ra), nasiatul, mubtadiin, 1]
# 298010                             [lya, &, nurul, (lyn)]
# 298818               [sekolah, dasar, negeri, (sdn), 190]
#
#                 SplitStreet                                           SplitRaw
# 898                   [duy]  [duy, ,, kary, novo, hotel, batam, (kop, novo)...
# 967               [dharmaw]  [eka, sari, lor, transport., pt, -, agen, ando...
# 4382                     []  [bank, rakyat, indonesia, (persero), tbk., pt,...
# 4547           [sul, agung]  [askes., pt, (persero), -, sema, ,, sul, agung...
# 7850             [dr, raji]  [dr, raji, no, 107, batik, artha, (mbak, muji)...
# ...                     ...                                                ...
# 296842                   []  [kebun, sayur, organik, (kso), dusun, wuni, ,,...
# 297334              [borob]  [pao, telo, (bak, telo), ,, borob, mojolangu, ...
# 297514                   []       [raudhatul, athfa, (ra), nasiatul, mubta, 1]
# 298010  [m, h, tham, boule]  [lya, &, nurul, (lyn), ,, m, h, tham, boule, ,...
# 298818            [r, kemu]  [sekolah, dasar, negeri, (sdn), 190, ,, r, kem...
#
# [498 rows x 8 columns]

# %%
df[df["Street"].apply(lambda x : "(" in x)]
# Out:
#             id                                        raw_address  \
# 213027  213027  rusunawa pesakih (rptra) , jl. daan mogot(desa...
# 273268  273268                             (j-2) 16 dadap kosambi
#
#                                            POI/street               POI  \
# 213027  rusunawa pesakih/jl. daan mogot(desa semanan)  rusunawa pesakih
# 273268                                         /(j-2)
#
#                               Street             SplitPOI  \
# 213027  jl. daan mogot(desa semanan)  [rusunawa, pesakih]
# 273268                         (j-2)                   []
#
#                               SplitStreet  \
# 213027  [jl., daan, mogot(desa, semanan)]
# 273268                            [(j-2)]
#
#                                                  SplitRaw
# 213027  [rusunawa, pesakih, (rptra), ,, jl., daan, mog...
# 273268                        [(j-2), 16, dadap, kosambi]

# %%
# check the frequency on test data
x = dft["raw_address"].apply(lambda x : "(" in x)
sum(x)
# Out:
# 1133

# %%
dft[dft["raw_address"].apply(lambda x : "(" in x)]
# Out:
#           id                                        raw_address
# 113      113   sd negeri 3 seunuddon 24393 seunuddon (seunudon)
# 143      143  sisun kel., 22736 angkola barat (padang sidemp...
# 161      161                     marga 13 buahbatu (margacinta)
# 224      224  jln karya baru no 41 b rt 12 rw 03 kel srengse...
# 242      242  ( konter data cell ) komplek puri citra blok a...
# ...      ...                                                ...
# 49706  49706           buana asri iv, 15 pinang pinang (penang)
# 49854  49854         pinang buana asri 12 15144 pinang (penang)
# 49915  49915  kp. tanah ungkuk, rt.002 003, ds. sarimukti (p...
# 49926  49926  dk. wijaya rt 1 rw 1 (selepan lor lapangan kop...
# 49984  49984           amir ham 3 jrebeng lor kedopok (kedopak)
#
# [1133 rows x 2 columns]

# %%
lb_tokens = []

# %%
for tokens in df["SplitPOI"].tolist() + df["SplitStreet"].tolist() :
    for token in tokens :
        if "(" in token :
            lb_tokens.append(token)

# %%
count = Counter(lb_tokens)

# %%
count.most_common()[:15]
# Out:
# [('(', 26),
#  ('(ra)', 24),
#  ('(sdn)', 20),
#  ('(mt)', 18),
#  ('(mis)', 13),
#  ('(persero)', 12),
#  ('(tpa', 12),
#  ('(tpq', 11),
#  ('(kua)', 9),
#  ('(tk)', 8),
#  ('(alfamart)', 7),
#  ('(tpq)', 7),
#  ('(smk)', 7),
#  ('(lkp)', 6),
#  ('(mission', 4)]

# %%
# remove "(" and ")" if it's not in one word
def remove_bracket(text) :
    words = text.split(" ")
    for i in range(len(words)) :
        if "(" in words[i] and  ")" not in words[i] :
            words[i] = words[i].replace("(", "")
        elif ")" in words[i] and  "(" not in words[i] :
            words[i] = words[i].replace(")", "")
    return " ".join(words).strip()

# %%
df["raw_address"] = df["raw_address"].apply(remove_bracket)
df["POI/street"] = df["POI/street"].apply(remove_bracket)

df[["POI", "Street"]] = df["POI/street"].str.split(" ", 1, expand=True)

df["SplitRaw"] = df["raw_address"].str.split(" ")
df["SplitPOI"] = df["POI"].str.split(" ")
df["SplitStreet"] = df["Street"].str.split(" ")

df
# Out:
#             id                                        raw_address  \
# 0            0  jl kapuk timur delta sili iii lippo cika 11 a ...
# 2            2               setu siung 119 rt 5 1 13880 cipayung
# 3            3                              toko dita , kertosono
# 4            4                                      jl. orde baru
# 5            5                  raya samb gede , 299 toko bb kids
# ...        ...                                                ...
# 299994  299994    karawaci baru kakap raya 156 rt 1 rw 3 karawaci
# 299995  299995               jend ahmad yani 331 kertasari ciamis
# 299996  299996                raya cila kko , cilandak timur kel.
# 299998  299998  jalan cipadu jaya taman asri gang bijaksana 3 ...
# 299999  299999           jaya maspion permata blok beryl b2 no 58
#
#                                        POI/street     POI  \
# 0       /jl kapuk timur delta sili iii lippo cika     /jl
# 2                                          /siung  /siung
# 3                                      toko dita/    toko
# 4                                  /jl. orde baru    /jl.
# 5                     toko bb kids/raya samb gede    toko
# ...                                           ...     ...
# 299994                                /kakap raya  /kakap
# 299995                           /jend ahmad yani   /jend
# 299996                             /raya cila kko   /raya
# 299998                                taman asri/   taman
# 299999                      jaya maspion permata/    jaya
#
#                                        Street  SplitPOI  \
# 0       kapuk timur delta sili iii lippo cika     [/jl]
# 2                                        None  [/siung]
# 3                                       dita/    [toko]
# 4                                   orde baru    [/jl.]
# 5                      bb kids/raya samb gede    [toko]
# ...                                       ...       ...
# 299994                                   raya  [/kakap]
# 299995                             ahmad yani   [/jend]
# 299996                               cila kko   [/raya]
# 299998                                  asri/   [taman]
# 299999                       maspion permata/    [jaya]
#
#                                           SplitStreet  \
# 0       [kapuk, timur, delta, sili, iii, lippo, cika]
# 2                                                None
# 3                                             [dita/]
# 4                                        [orde, baru]
# 5                         [bb, kids/raya, samb, gede]
# ...                                               ...
# 299994                                         [raya]
# 299995                                  [ahmad, yani]
# 299996                                    [cila, kko]
# 299998                                        [asri/]
# 299999                            [maspion, permata/]
#
#                                                  SplitRaw
# 0       [jl, kapuk, timur, delta, sili, iii, lippo, ci...
# 2           [setu, siung, 119, rt, 5, 1, 13880, cipayung]
# 3                              [toko, dita, ,, kertosono]
# 4                                       [jl., orde, baru]
# 5              [raya, samb, gede, ,, 299, toko, bb, kids]
# ...                                                   ...
# 299994  [karawaci, baru, kakap, raya, 156, rt, 1, rw, ...
# 299995        [jend, ahmad, yani, 331, kertasari, ciamis]
# 299996        [raya, cila, kko, ,, cilandak, timur, kel.]
# 299998  [jalan, cipadu, jaya, taman, asri, gang, bijak...
# 299999  [jaya, maspion, permata, blok, beryl, b2, no, 58]
#
# [265889 rows x 8 columns]

# %%
df[["id", "raw_address", "POI/street"]].to_csv(data_dir + "processed_train.csv", index=False)

# %% [markdown]
# ## Create the whole text processing pipeline

# %%
dft = pd.read_csv(data_dir + "test.csv")

# %%
def preprocess_text(text) :
    text = remove_multiple_whitespace(text)
    text = remove_dot(text)
    text = restructure_comma(text)
    text = remove_bracket(text)
    return text

dft["raw_address"] = dft["raw_address"].apply(preprocess_text)

# %%
dft
# Out:
#           id                                        raw_address
# 0          0              s. par 53 sidanegara 4 cilacap tengah
# 1          1             angg per , baloi indah kel. lubuk baja
# 2          2                            asma laun , mand imog ,
# 3          3     ud agung rej , raya nga sri wedari karanganyar
# 4          4                        cut mutia , 35 baiturrahman
# ...      ...                                                ...
# 49995  49995                    toko mbak farid semboro semboro
# 49996  49996   vie - tk. ridho kids , vete 3 cari , 16720 ciawi
# 49997  49997              mart dan roti bakar malabar , nasio ,
# 49998  49998  graha indah pamulang jl. mujair raya bambu apu...
# 49999  49999                                              adi ,
#
# [50000 rows x 2 columns]

# %%
dft.to_csv(data_dir + "processed_test.csv", index=False)
